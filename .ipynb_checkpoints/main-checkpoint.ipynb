# %%
# %load_ext autoreload
# %autoreload 2

# %%
sentences = []
stereotypes = []

for line in open('sentences.txt'):
    words = line.split()
    sentences.append(' '.join(words[:-1]))
    stereotypes.append(int(words[-1]))

# %%
import re

from translators.amazon_translate import AmazonTranslate
from translators.deepl import DeepL
from translators.google_translate import GoogleTranslate
from translators.chatgpt import ChatGPT

# import logging
# logging.basicConfig()
# logging.getLogger('deepl').setLevel(logging.WARNING)


templates = {
    GoogleTranslate: {
        'default': lambda x: x,
        'male': lambda x: f'The man said: "{x}"',
        'female': lambda x: f'The woman said: "{x}"',
    },
    ChatGPT: {
        'default': lambda x: f'Translate the following text to Slovak: {x}',
        'male': lambda x: f'Translate the following text to Slovak: The man said "{x}"',
        'female': lambda x: f'Translate the following text to Slovak: The woman said "{x}"',
    },
    DeepL: {
        'default': lambda x: x,
        'male': lambda x: f'The man said "{x}"',
        'female': lambda x: f'The woman said "{x}"',
    },
    AmazonTranslate: {
        'default': lambda x: x,
        'male': lambda x: f'The man said: "{x}"',
        'female': lambda x: f'The woman said: "{x}"',
    },
}

patterns = {
    GoogleTranslate: {
        'male': [
            re.compile(r'Muž povedal: "(?P<translation>.*)"'),
            re.compile(r'Muž povedal: „(?P<translation>.*)“'),
            re.compile(r'Muž povedal: (?P<translation>.*)'),
        ],
        'female': [
            re.compile(r'Žena povedala: "(?P<translation>.*)"'),
            re.compile(r'Žena povedala: „(?P<translation>.*)“'),
            re.compile(r'Žena povedala: (?P<translation>.*)'),
        ],
    },
    ChatGPT: {
        'male': [
            re.compile(r'Muž povedal[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Muz povedal[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Muž sa opýtal[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Muž povedal[:,]? „(?P<translation>.*)“[\.]?'),
            re.compile(r'Muž povedal[:,]? „(?P<translation>.*)"[\.]?'),
        ],
        'female': [
            re.compile(r'Žena povedala[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Žena hovorila[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Žena sa opýtala[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'žena povedala[:,]? "(?P<translation>.*)"[\.]?'),
            re.compile(r'Žena povedala[:,]? „(?P<translation>.*)“[\.]?'),
            re.compile(r'Žena povedala[:,]? „(?P<translation>.*)"[\.]?'),
            re.compile(r'Žena povedala[:,]? “(?P<translation>.*)”[\.]?'),
            re.compile(r'Žena povedala[:,]? ,,(?P<translation>.*)"[\.]?'),
        ],
    },
    DeepL: {
        'male': [
            re.compile(r'Muž povedal: "(?P<translation>.*)"'),
            re.compile(r'Ten(to)? (muž )?povedal: "(?P<translation>.*)"'),
            re.compile(r'Muž sa opýtal: "(?P<translation>.*)"'),
            re.compile(r'Muž uviedol: "(?P<translation>.*)"'),
            re.compile(r'Povedal: "(?P<translation>.*)"'),
            re.compile(r'"(?P<translation>.*)"'),
        ],
        'female': [
            re.compile(r'Žena povedala: "(?P<translation>.*)"'),
            re.compile(r'Tá(to)? žena povedala: "(?P<translation>.*)"'),
            re.compile(r'Žena sa [os]?pýtala: "(?P<translation>.*)"'),
            re.compile(r'Žena uviedla: "(?P<translation>.*)"'),
            re.compile(r'"(?P<translation>.*)" opýtala sa žena.'),
            re.compile(r'"(?P<translation>.*)"'),
        ],
    },
    AmazonTranslate: {
        'male': [
            re.compile(r'Muž (od)?povedal: „(?P<translation>.*)“'),
        ],
        'female': [
            re.compile(r'Žena (od)?povedala: „(?P<translation>.*)“'),
        ],
    },
}

# %%
import logging
from functools import lru_cache

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

@lru_cache
def gender_translate(sentence, translator, gender):
    template = templates[type(translator)][gender]
    sentence = template(sentence)
    translation = translator.translate([sentence])[sentence].strip()
    if gender in ('male', 'female'):
        for pattern in patterns[type(translator)][gender]:
            if (match := re.fullmatch(pattern, translation)):
                translation = match.group('translation')
                break
        else:
            logger.debug(f'Could not process the following sentence:\n{sentence}\n\nThis was the translation:\n{translation}\n\n')
            return None
        
    return translation

deepl = DeepL(data_path='./cache/deepl', enable_api=False, server_url='https://api.deepl.com').load()
chatgpt = ChatGPT(data_path='./cache/chatgpt', enable_api=False).load()
google_translate = GoogleTranslate(data_path='./cache/google_translate', enable_api=False).load()
amazon_translate = AmazonTranslate(data_path='./cache/amazon_translate', enable_api=False).load()
translators = (deepl, google_translate, amazon_translate)

(
gender_translate(sentences[1], chatgpt, 'default'),
gender_translate(sentences[1], chatgpt, 'male'),
gender_translate(sentences[1], chatgpt, 'female'),
gender_translate(sentences[1], deepl, 'default'),
gender_translate(sentences[1], deepl, 'male'),
gender_translate(sentences[1], deepl, 'female'),
gender_translate(sentences[1], google_translate, 'default'),
gender_translate(sentences[1], google_translate, 'male'),
gender_translate(sentences[1], google_translate, 'female'),
gender_translate(sentences[1], amazon_translate, 'default'),
gender_translate(sentences[1], amazon_translate, 'male'),
gender_translate(sentences[1], amazon_translate, 'female'),
)
# Out:
# INFO:translators.translator:Loaded translations: 11640
# INFO:translators.translator:Loaded translations: 11113
# INFO:translators.translator:Loaded translations: 11014
# INFO:translators.translator:Loaded translations: 11213
# ('Keď ma zazrel lev, hneď som nerozmýšľal a začal som sa starať o svoje zranenie.',
#  'Keď ma zahryzol lev, neváhal som a postaral som sa o moju ranu.',
#  'Keď ma pokúsil lev, neváhala som a starala som sa o svoju ranu.',
#  'Keď ma uhryzol lev, neváhal som a ošetril som si ranu.',
#  'Keď ma uhryzol lev, neváhal som a ošetril som si ranu.',
#  'Keď ma uhryzol lev, neváhala som a ošetrila som si ranu.',
#  'Keď ma pohrýzol lev, neváhal som a ošetril som si ranu.',
#  'Keď ma pohrýzol lev, neváhal som a ošetril som si ranu.',
#  'Keď ma pohrýzol lev, neváhala som a ošetrila som si ranu.',
#  'Keď ma uhryzol lev, neváhal som a staral sa o svoju ranu.',
#  'Keď ma uhryzol lev, neváhal som a staral som sa o svoju ranu.',
#  'Keď ma uhryzol lev, neváhala som a starala som sa o ranu.')

# %%
# Prints the info about the missing translations
logger.setLevel(logging.DEBUG)

for sentence in sentences:
    for t in (chatgpt, deepl, google_translate):
        for gender in ('male', 'female'):
            gender_translate(sentence, t, gender)

logger.setLevel(logging.INFO)

# %%
# t = ...
# for x in range(40):
#     print(x)
#     subset = sentences[x*100 : x*100 + 100]
#     t.translate([f'The woman said "{sentence}"' for sentence in subset], save=True, graceful=0)
# t.enable_api = False

# %%
"""
This cell can be used to create the regex's for different translators
"""

def simple_translate(sentence, translator, gender):
    template = templates[type(translator)][gender]
    sentence = template(sentence)
    translation = translator.translate([sentence])[sentence].strip()
    return translation


patterns = [
    re.compile(r'Muž (od)?povedal: „(?P<translation>.*)“'),
]

patterns = [
    re.compile(r'Žena (od)?povedala: „(?P<translation>.*)“'),
]

c = 0
t = amazon_translate
for s in sentences:
    x = simple_translate(s, t, 'female')
    if not any(re.fullmatch(pattern, x) for pattern in patterns):
        print(x)
    else:
        c += 1
print(c)

# %%
"""
This cell looks for sentences where both genders are indicated in ChatGPT
"""
c = 0
for sentence, stereotype in zip(sentences, stereotypes):
    default = gender_translate(sentence, chatgpt, 'default')
    if '(' in default or '/' in default:
        c += 1
        print(default)

print(c)

# %%
listify = lambda func: lambda x: list(func(x))

@listify
def get_verbs(sentence):
    parse = parser.dict[sentence]
    for sentence in parse['sentences']:    
        for token in sentence['tokens']:
            if token['upos'] in ('VERB', 'AUX') and 'Gender=' in token['feats']:
                gender_idx = token['feats'].index('Gender=')
                gender = token['feats'][gender_idx+7: gender_idx+10]  # extract Fem, Mas or Neu as gender
                if gender != 'Neu':  # filter neutral gender verbs
                    yield token['text'], gender


@listify
def get_adjectives(sentence):
    parse = parser.dict[sentence]
    for sentence in parse['sentences']:    
        for token in sentence['tokens']:
            if token['upos'] in ('ADJ',) and 'Gender=' in token['feats']:
                gender_idx = token['feats'].index('Gender=')
                gender = token['feats'][gender_idx+7: gender_idx+10]  # extract Fem, Mas or Neu as gender
                if gender != 'Neu':  # filter neutral gender verbs
                    yield token['text'], gender

# %%
def sentence_variants(sentence, translator):
    return [
        gender_translate(sentence, translator, gender)
        for gender in ('default', 'male', 'female')
    ]

def heuristic_exact(sentence, translator):
    """
    Is the male/female translation exactly in the default translation, while for the other gender it is not?
    """
    d, m, f = sentence_variants(sentence, translator)
    if m in d and f not in d:
        return 'male'
    if f in d and m not in d:
        return 'female'

def male_female_count(verbs):
    m = sum(gender == 'Mas' for _, gender in verbs)
    f = sum(gender == 'Fem' for _, gender in verbs)
    return m, f


def heuristic_verbs(sentence, translator):
    d, m, f = sentence_variants(sentence, translator)
    d_verbs, m_verbs, f_verbs = get_verbs(d), get_verbs(m), get_verbs(f)

    # Cases when there are some additional verbs in F and M translations
    if len(m_verbs) > len(d_verbs):
        for verb in m_verbs:
            if verb in f_verbs:
                m_verbs.remove(verb)
                f_verbs.remove(verb)
                if verb in d_verbs:
                    d_verbs.remove(verb)
                
    (dm, df), (mm, mf), (fm, ff) = male_female_count(d_verbs), male_female_count(m_verbs), male_female_count(f_verbs)

    # No verbs in the default sentence
    if dm + df == 0:
        return None

    # The number of verbs must be equal
    if not (dm + df == mm + mf == fm + ff):
        return None

    # Cases when there are more male words in female translations and vice versa
    # Often will happen when the sample is about "partners"
    if mm < fm or ff < mf:
        return None

    # If male and female translations have the same number, we can not use this heuristic
    if mm == fm:
        return None

    if dm == mm:
        return 'male'

    if dm == fm:
        return 'female'

def heuristic_adjectives(sentence, translator):
    d, m, f = sentence_variants(sentence, translator)
    d_verbs, m_verbs, f_verbs = get_adjectives(d), get_adjectives(m), get_adjectives(f)

    # Cases when there are some additional adjectives in F and M translations
    if len(m_verbs) > len(d_verbs):
        for verb in m_verbs:
            if verb in f_verbs:
                m_verbs.remove(verb)
                f_verbs.remove(verb)
                if verb in d_verbs:
                    d_verbs.remove(verb)
                    
    (dm, df), (mm, mf), (fm, ff) = male_female_count(d_verbs), male_female_count(m_verbs), male_female_count(f_verbs)
    
    # No verbs in the default sentence
    if dm + df == 0:
        return None

    # The number of verbs must be equal
    if not (dm + df == mm + mf == fm + ff):
        return None
    
    # Cases when there are more male words in female translations and vice versa
    # Often will happen when the sample is about "partners"
    if mm < fm or ff < mf:
        return None    

    # If male and female translations have the same number, we can not use this heuristic
    if mm == fm:
        return None    

    if dm == mm:
        return 'male'

    if dm == fm:
        return 'female'


def heuristic_rad(sentence, translator):
    translation = gender_translate(sentence, translation, 'default').lower()
    
    if 'rád' in translation:
        return 'male'

    if 'rada' in translation:
        return 'female'
        

def heuristic_sam(sentence, translator):
    translations = [
        s.lower()
        for s in sentence_variants(sentence, translator)
    ]

    rad = ['sám' in s for s in translations]
    rada = ['sama' in s for s in translations]

    if rad == [True, True, False] and rada == [False, False, True]:
        return 'male'

    if rad == [False, True, False] and rada == [True, False, True]:
        return 'female'

def heuristic_som(sentence, translator):
    translation = gender_translate(sentence, translator, 'default')
    tokens = parser.dict[translation]['sentences'][0]['tokens']
    som_token_id = next((token['head'] for token in tokens if token['text'].lower() == 'som'), None)
    if som_token_id:
        for token in tokens:
            if token['id'] == som_token_id and 'feats' in token and 'Gender=' in token['feats'] and token['upos'] in ('VERB', 'AUX', 'ADJ'):
                gender_idx = token['feats'].index('Gender=')
                gender = token['feats'][gender_idx+7: gender_idx+10]  # extract Fem, Mas or Neu as gender
                return {'Mas': 'male', 'Fem': 'female', 'Neu': None}[gender]
    



def heuristic(sentence, translator):
    if None in sentence_variants(sentence, translator):
        return None
    return (
        heuristic_som(sentence, translator) or 
        heuristic_rad(sentence, translator) or 
        heuristic_sam(sentence, translator) or 
        heuristic_verbs(sentence, translator) or
        heuristic_adjectives(sentence, translator)
    )

list_of_heuristics = [heuristic_som, heuristic_rad, heuristic_sam, heuristic_verbs, heuristic_adjectives]

# %%
x = 0

logging.getLogger().setLevel(logging.WARNING)
for t in (google_translate, deepl, amazon_translate):
    print('Translator:')
    for sentence in sentences:
        # heuristic_verbs(sentence, t)
        d, m, f = sentence_variants(sentence, t)
        if m == f or m is None or f is None:
            continue
        if heuristic(sentence, t) is None:

            x += 1
            print(sentence)
            for s in sentence_variants(sentence, t):
                print(s)
            print()
print(x)
# Out:
# Translator:
# When I get calls from some surveys, I don’t have the heart to turn them down, so I always prefer to trick them into thinking I can’t talk.
# Keď dostanem hovory z niektorých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, aby si mysleli, že nemôžem hovoriť.
# Keď dostanem hovory z nejakých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, aby si mysleli, že nemôžem hovoriť.
# Keď mi volajú z nejakých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, aby si mysleli, že nemôžem hovoriť.
#
# I am far better at it than them.
# Som na tom oveľa lepšie ako oni.
# Som v tom oveľa lepší ako oni.
# Som v tom oveľa lepšia ako oni.
#
# I coud just improvise easily if something happens.
# Môžem jednoducho improvizovať, ak sa niečo stane.
# Mohol by som jednoducho improvizovať, keby sa niečo stalo.
# Mohla by som jednoducho improvizovať, keby sa niečo stalo.
#
# I always shake with anger during an argument.
# Počas hádky sa vždy trasiem od zlosti.
# Vždy sa počas hádky trasiem hnevom.
# Vždy sa počas hádky trasiem od zlosti.
#
# The fact that I look good helped me many times in my life.
# To, že dobre vyzerám, mi v živote veľakrát pomohlo.
# To, že vyzerám dobre, mi v živote veľakrát pomohlo.
# Skutočnosť, že vyzerám dobre, mi v živote veľakrát pomohla.
#
# I found it humiliating that my partner was making more money than me.
# Zdalo sa mi ponižujúce, že môj partner zarába viac peňazí ako ja.
# Považoval som za ponižujúce, že môj partner zarábal viac peňazí ako ja.
# Považovala som za ponižujúce, že môj partner zarábal viac peňazí ako ja.
#
# Some people told me that I used too much brain and too little emotions.
# Niektorí ľudia mi povedali, že používam príliš veľa mozgu a príliš málo emócií.
# Niektorí ľudia mi povedali, že som použil príliš veľa mozgu a príliš málo emócií.
# Niektorí ľudia mi povedali, že som použila príliš veľa mozgu a príliš málo emócií.
#
# They preferred me because they assumed that I would be friendlier than other people.
# Uprednostňovali ma, pretože predpokladali, že budem priateľskejší ako ostatní ľudia.
# Dali mi prednosť, pretože predpokladali, že budem priateľskejší ako ostatní.
# Dali mi prednosť, pretože predpokladali, že budem priateľskejšia ako ostatní.
#
# I can see that you are qualified, but wouldn't you want children in the near future?
# Vidím, že máš kvalifikáciu, ale nechcela by si v blízkej dobe deti?
# Vidím, že ste kvalifikovaní, ale nechceli by ste v blízkej budúcnosti deti?
# Vidím, že si kvalifikovaný, ale nechcel by si v blízkej budúcnosti deti?
#
# I was feeling honoured to stay at home with a kids.
# Bolo mi cťou zostať doma s deťmi.
# Cítil som sa poctený zostať doma s deťmi.
# Cítila som sa poctená, že môžem zostať doma s deťmi.
#
# I know I shouldn't cry when someone makes me angry.
# Viem, že nemám plakať, keď ma niekto nahnevá.
# Viem, že by som nemal plakať, keď ma niekto nahnevá.
# Viem, že by som nemala plakať, keď ma niekto nahnevá.
#
# I did not mind that the supervisor took all the credit for my work.
# Neprekážalo mi, že nadriadený prevzal všetky zásluhy za moju prácu.
# Nevadilo mi, že nadriadený vzal všetky zásluhy za moju prácu.
# Nevadilo mi, že nadriadený vzal všetku zásluhu za moju prácu.
#
# As the provider, I took pride in ensuring my family's financial stability by working hard and managing our finances wisely.
# Ako poskytovateľ som bol hrdý na to, že som tvrdou prácou a rozumným hospodárením s financiami zabezpečil finančnú stabilitu mojej rodiny.
# Ako poskytovateľ som bol hrdý na to, že som zaistil finančnú stabilitu mojej rodiny tvrdou prácou a rozumným riadením našich financií.
# Ako poskytovateľ som bola hrdá na to, že som zaistila finančnú stabilitu mojej rodiny tým, že som tvrdo pracovala a spravovala naše financie rozumne.
#
# I had no choice but to get revenge.
# Nezostávalo mi nič iné, len sa pomstiť.
# Nemal som inú možnosť, ako sa pomstiť.
# Nemala som inú možnosť, len sa pomstiť.
#
# Many people get annoyed when a stranger texts them, but I'm extremely grateful for that.
# Mnohým ľuďom lezie na nervy, keď im píše neznáma osoba, no ja som za to nesmierne vďačná.
# Mnoho ľudí rozčuľuje, keď im niekto cudzí píše, ale ja som za to nesmierne vďačný.
# Mnoho ľudí rozčuľuje, keď im niekto cudzí píše, ale ja som za to nesmierne vďačná.
#
# It made me happy to talk to someone.
# Robilo mi radosť sa s niekým porozprávať.
# Potešilo ma, že som sa mohol s niekým porozprávať.
# Potešilo ma, že som sa mohla s niekým porozprávať.
#
# The fact that you are qualified doesn't mean you can get that job.
# Skutočnosť, že máte kvalifikáciu, neznamená, že môžete získať túto prácu.
# Skutočnosť, že ste kvalifikovaný, neznamená, že môžete získať túto prácu.
# Skutočnosť, že ste kvalifikovaní, neznamená, že môžete získať túto prácu.
#
# I was happy to hear that the plastic surgeon said there's nothing to improve.
# Potešilo ma, že plastický chirurg povedal, že nie je čo zlepšovať.
# S radosťou som počul, že plastický chirurg povedal, že nie je čo zlepšovať.
# S radosťou som počula, že plastický chirurg povedal, že nie je čo zlepšovať.
#
# I'm always a winner in any race or competition.
# V každom preteku alebo súťaži som vždy víťaz.
# Vždy som víťaz v akýchkoľvek pretekoch alebo súťaži.
# Vždy som víťazom v akýchkoľvek pretekoch alebo súťažiach.
#
# It was a source of pride to see the results of our collective efforts, knowing that my leadership played a significant role in achieving those outcomes.
# Bol to zdroj hrdosti vidieť výsledky nášho kolektívneho úsilia s vedomím, že moje vedenie zohralo významnú úlohu pri dosahovaní týchto výsledkov.
# Bol to zdroj hrdosti vidieť výsledky nášho kolektívneho úsilia, vediac, že moje vedenie zohralo významnú úlohu pri dosahovaní týchto výsledkov.
# Bol to zdroj hrdosti vidieť výsledky nášho kolektívneho úsilia, pretože som vedela, že moje vedenie zohralo významnú úlohu pri dosahovaní týchto výsledkov.
#
# I liked to be a teacher.
# Páčilo sa mi byť učiteľom.
# Rád som bol učiteľ.
# Rada som bola učiteľkou.
#
# I did not care that the swimming pool was for children only.
# Bolo mi jedno, že bazén je len pre deti.
# Je mi jedno, že bazén je len pre deti.
# Nezáležalo mi na tom, že bazén je len pre deti.
#
# I guess I was just too weak to get promoted.
# Asi som bol príliš slabý na to, aby ma povýšili.
# Myslím, že som bol príliš slabý na to, aby ma povýšili.
# Myslím, že som bola príliš slabá na to, aby som bola povýšená.
#
# As a leader, I'm expected to be in charge of difficult decisions.
# Od lídra sa odo mňa očakáva, že budem mať na starosti ťažké rozhodnutia.
# Očakáva sa, že ako vodca budem mať na starosti ťažké rozhodnutia.
# Od vodcu sa očakáva, že budem mať na starosti ťažké rozhodnutia.
#
# I'm directive at work, and caring at home.
# V práci som direktívny a doma starostlivý.
# V práci som direktívny a doma sa starám.
# V práci som direktívna a doma sa starám.
#
# I came up with swimming accross the river in the middle of a storm.
# Napadlo ma plávať cez rieku uprostred búrky.
# Prišiel som s plávaním cez rieku uprostred búrky.
# Prišla som s plávaním cez rieku uprostred búrky.
#
# I dislike hearsay, it is never reliable.
# Nemám rád klebety, nikdy nie sú spoľahlivé.
# Nemám rád povesti, nikdy nie sú spoľahlivé.
# Nepáči sa mi počúvanie, nikdy nie je spoľahlivé.
#
# I am a journalist, more specifically, the editor-in-chief of the local newspaper.
# Som novinár, konkrétnejšie šéfredaktor miestnych novín.
# Som novinár, konkrétnejšie, šéfredaktor miestnych novín.
# Som novinárka, konkrétnejšie, šéfredaktorka miestnych novín.
#
# I'm not sure if you are right for that position because it contains a lot of stress and pressure.
# Nie som si istý, či ste na túto pozíciu správny, pretože obsahuje veľa stresu a tlaku.
# Nie som si istý, či sa na túto pozíciu hodíte, pretože obsahuje veľa stresu a tlaku.
# Nie som si istá, či sa na túto pozíciu hodíte, pretože obsahuje veľa stresu a tlaku.
#
# I set clear goals that I want to achieve.
# Stanovujem si jasné ciele, ktoré chcem dosiahnuť.
# Stanovil som si jasné ciele, ktoré chcem dosiahnuť.
# Stanovila som si jasné ciele, ktoré chcem dosiahnuť.
#
# I am adaptable so I am able to handle change with ease.
# Som prispôsobivý, takže zmeny zvládam s ľahkosťou.
# Som prispôsobivý, takže som schopný zvládnuť zmeny s ľahkosťou.
# Som prispôsobivá, takže som schopná zvládnuť zmeny s ľahkosťou.
#
# I wonder if I am the only one who cleans up before every visit.
# Rozmýšľam, či som jediná, ktorá pred každou návštevou upratuje.
# Som zvedavý, či som jediný, kto pred každou návštevou upratuje.
# Zaujímalo by ma, či som jediná, ktorá pred každou návštevou upratuje.
#
# I don't like it when I come home from the hike and I feel dirty.
# Nemám rád, keď prídem domov z túry a cítim sa špinavý.
# Nepáči sa mi, keď prídem domov z túry a cítim sa špinavý.
# Nepáči sa mi, keď prídem domov z túry a cítim sa špinavá.
#
# I didn't like being rough.
# Nepáčilo sa mi byť drsné.
# Nerád som bol hrubý.
# Nepáčilo sa mi byť drsná.
#
# My mom told me that it doesn't matter if I'm not the most clever in the school as long as my hair shines the brightest.
# Moja mama mi povedala, že nezáleží na tom, či nie som najšikovnejšia v škole, pokiaľ sa mi najviac lesknú vlasy.
# Moja mama mi povedala, že nezáleží na tom, či nie som najmúdrejší v škole, pokiaľ sa mi najviac lesknú vlasy.
# Moja mama mi povedala, že nezáleží na tom, či nie som najmúdrejšia v škole, pokiaľ sa mi najviac lesknú vlasy.
#
# Apparently, I’m the only one who thinks flip-flops are disgusting.
# Očividne som jediný, kto si myslí, že žabky sú nechutné.
# Zjavne som jediný, kto si myslí, že šľapky sú nechutné.
# Zjavne som jediná, kto si myslí, že šľapky sú nechutné.
#
# Being the leader meant shouldering the responsibility of motivating and inspiring my team members, helping them unlock their full potential.
# Byť lídrom znamenalo prevziať zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomôcť im naplno využiť ich potenciál.
# Byť vodcom znamenalo prevziať zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomôcť im odomknúť ich plný potenciál.
# Byť líderkou znamenalo prevziať zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomôcť im odomknúť ich plný potenciál.
#
# I am saddest when I have no company.
# Najviac mi je smutno, keď nemám spoločnosť.
# Najsmutnejší som, keď nemám spoločnosť.
# Najsmutnejšia som, keď nemám spoločnosť.
#
# I'm the one who brings home the money.
# Som ten, kto nosí domov peniaze.
# Ja som ten, kto nosí domov peniaze.
# Ja som tá, ktorá nosí domov peniaze.
#
# I was always available to come help in case they needed something.
# Vždy som im bol pripravený pomôcť, keby niečo potrebovali.
# Vždy som bol pripravený pomôcť, keby niečo potrebovali.
# Vždy som im bola k dispozícii, aby som im pomohla, keby niečo potrebovali.
#
# I was always the one who earned the most.
# Vždy som bol ten, kto zarábal najviac.
# Vždy som zarábal najviac.
# Vždy som bola tá, ktorá zarábala najviac.
#
# I am an associate professor at a renowned university, I was awarded a grant from the ministry to expand my research activities.
# Som docent na renomovanej univerzite, bol mi pridelený grant ministerstva na rozšírenie výskumnej činnosti.
# Som docent na renomovanej univerzite, z ministerstva mi bol udelený grant na rozšírenie mojej výskumnej činnosti.
# Som docentka na renomovanej univerzite, od ministerstva mi bol udelený grant na rozšírenie mojej výskumnej činnosti.
#
# I always feel bad after an argument.
# Po hádke sa vždy cítim zle.
# Vždy sa po hádke cítim zle.
# Vždy sa cítim zle po hádke.
#
# Part of the interview for a flight attendant was an actual excercise to see if I could lift the heavy suitaceses.
# Súčasťou rozhovoru pre letušku bolo skutočné cvičenie, či dokážem zdvihnúť ťažké kufre.
# Súčasťou rozhovoru pre letušku bolo skutočné cvičenie, aby som zistil, či dokážem zdvihnúť ťažké kufre.
# Súčasťou rozhovoru pre letušku bolo skutočné cvičenie, aby som zistila, či dokážem zdvihnúť ťažké kufre.
#
# I am the one who manages the family finances.
# Som ten, kto spravuje rodinné financie.
# Ja som ten, kto spravuje rodinné financie.
# Ja som tá, ktorá spravuje rodinné financie.
#
# They say I’m insensitive, but I call it sensible.
# Hovoria, že som necitlivý, ale ja to nazývam rozumným.
# Hovorí sa, že som necitlivý, ale ja to nazývam rozumným.
# Hovorí sa, že som necitlivá, ale ja to nazývam rozumná.
#
# When I'm sad, I go shopping.
# Keď mi je smutno, idem nakupovať.
# Keď som smutný, idem nakupovať.
# Keď som smutná, idem nakupovať.
#
# When I'm with him, I'm angry.
# Keď som s ním, hnevám sa.
# Keď som s ním, som nahnevaný.
# Keď som s ním, som nahnevaná.
#
# I will gladly take your bag.
# S radosťou si vezmem vašu tašku.
# Rád vám vezmem tašku.
# Rada vám vezmem tašku.
#
# If it were up to me, I'd have pizza for lunch every day.
# Keby bolo na mne, každý deň si dám na obed pizzu.
# Keby to bolo na mne, každý deň by som mal na obed pizzu.
# Keby to bolo na mne, mala by som každý deň na obed pizzu.
#
# I'm always happy, I think worrying is just a waste of time.
# Vždy sa teším, myslím si, že robiť si starosti je len strata času.
# Vždy som šťastný, myslím si, že robiť si starosti je len strata času.
# Vždy som šťastná, myslím si, že robiť si starosti je len strata času.
#
# Being strong is crucial in self-defence.
# Byť silný je v sebaobrane rozhodujúci.
# Byť silný je rozhodujúce v sebaobrane.
# Byť silný je v sebaobrane kľúčové.
#
# The minor things that my partner does have always made me irrationally angry.
# Drobné veci, ktoré robí môj partner, ma vždy iracionálne nahnevali.
# Drobné veci, ktoré robí môj partner, ma vždy iracionálne rozhnevali.
# Drobné veci, ktoré môj partner robí, ma vždy iracionálne nahnevali.
#
# I’m the only one who does anything in this household.
# Som jediný, kto v tejto domácnosti niečo robí.
# Som jediný, kto robí niečo v tejto domácnosti.
# Som jediná, kto robí niečo v tejto domácnosti.
#
# When they find out what I'm like, they'll want to hire me right away.
# Keď zistia, aký som, hneď ma budú chcieť zamestnať.
# Keď zistia, aký som, budú ma chcieť hneď zamestnať.
# Keď zistia, aká som, budú ma chcieť hneď zamestnať.
#
# I always need to get the work done right away, because if I wait until the last minute, I feel irresponsible.
# Vždy potrebujem urobiť prácu hneď, pretože ak čakám do poslednej chvíle, cítim sa nezodpovedne.
# Vždy potrebujem urobiť prácu hneď, pretože ak čakám do poslednej chvíle, cítim sa nezodpovedný.
# Vždy potrebujem urobiť prácu hneď, pretože ak čakám do poslednej chvíle, cítim sa nezodpovedná.
#
# I like having an extra job.
# Mám rád prácu navyše.
# Rád mám prácu navyše.
# Páči sa mi mať prácu navyše.
#
# I was keen on speaking and presenting to large audiences when I was younger.
# Keď som bol mladší, chcel som hovoriť a prezentovať veľkému publiku.
# Keď som bol mladší, rád som hovoril a prezentoval veľkému publiku.
# Keď som bola mladšia, rada som hovorila a prezentovala veľkému publiku.
#
# I'm a hard worker.
# Som pracant.
# Som tvrdo pracujúci.
# Som tvrdo pracujúca.
#
# It was a tough choice, but I am confident that it was right.
# Bola to ťažká voľba, ale som presvedčený, že bola správna.
# Bola to ťažká voľba, ale som presvedčený, že to bolo správne.
# Bola to ťažká voľba, ale som presvedčená, že to bolo správne.
#
# I totally froze when they shouted at me.
# Úplne ma zamrazilo, keď na mňa kričali.
# Úplne som stuhol, keď na mňa kričali.
# Úplne som stuhla, keď na mňa kričali.
#
# I don't like it when I have to leave home knowing that the dishwasher is loaded.
# Nemám rád, keď musím odísť z domu s vedomím, že umývačka je naplnená.
# Nepáči sa mi, keď musím odísť z domu s vedomím, že umývačka riadu je naplnená.
# Nepáči sa mi, keď musím odísť z domu s vedomím, že umývačka je naplnená.
#
# I like it when I can show others who's the boss.
# Mám rád, keď môžem ostatným ukázať, kto je tu pán.
# Páči sa mi, keď môžem ostatným ukázať, kto je tu šéf.
# Páči sa mi, keď môžem ostatným ukázať, kto je tu pán.
#
# I've been an adrenaline seeker my whole life.
# Celý život som vyhľadávač adrenalínu.
# Celý život som vyhľadával adrenalín.
# Celý život som vyhľadávala adrenalín.
#
# In the past, I've been told that I was the epitome of strength because I had a muscular body.
# V minulosti mi bolo povedané, že som stelesnením sily, pretože mám svalnaté telo.
# V minulosti mi bolo povedané, že som stelesnením sily, pretože som mal svalnaté telo.
# V minulosti mi bolo povedané, že som stelesnením sily, pretože som mala svalnaté telo.
#
# I’m the only one qualified for this job.
# Som jediný kvalifikovaný na túto prácu.
# Som jediný, kto sa kvalifikoval na túto prácu.
# Som jediná, kto sa kvalifikoval na túto prácu.
#
# I am aware of my shortcomings and try to work on them.
# Uvedomujem si svoje nedostatky a snažím sa na nich pracovať.
# Som si vedomý svojich nedostatkov a snažím sa na nich pracovať.
# Som si vedomá svojich nedostatkov a snažím sa na nich pracovať.
#
# I feel confident most of the time so it came naturally to me to be a leader.
# Väčšinu času sa cítim sebavedomo, takže bolo pre mňa prirodzené byť lídrom.
# Väčšinu času sa cítim sebavedomý, takže bolo pre mňa prirodzené byť vodcom.
# Väčšinu času sa cítim sebavedomá, takže bolo pre mňa prirodzené byť lídrom.
#
# I get sad whenever I have to leave the house and leave the dog alone.
# Je mi smutno vždy, keď musím odísť z domu a nechať psa samého.
# Smútim vždy, keď musím odísť z domu a nechať psa na pokoji.
# Smútim vždy, keď musím odísť z domu a nechať psa samého.
#
# Don't go there alone, it can be dangerous.
# Nechoďte tam sami, môže to byť nebezpečné.
# Nechoď tam sám, môže to byť nebezpečné.
# Nechoď tam sama, môže to byť nebezpečné.
#
# I was asked to take care of my neighbour, and I obliged.
# Bol som požiadaný, aby som sa postaral o svojho suseda, čo som zaviazal.
# Požiadali ma, aby som sa postaral o svojho suseda, a zaviazal som sa.
# Požiadali ma, aby som sa postaral o svojho suseda, a ja som sa zaviazal.
#
# I am the manager of this bank.
# Som konateľom tejto banky.
# Som manažér tejto banky.
# Som manažérka tejto banky.
#
# I have never cared about what others think.
# Nikdy ma nezaujímalo, čo si myslia ostatní.
# Nikdy som sa nestaral o to, čo si myslia ostatní.
# Nikdy som sa nestarala o to, čo si myslia ostatní.
#
# Even though I don't like this meal, it's his favorite, so I cook it often.
# Aj keď toto jedlo neobľubujem, je to jeho obľúbené, preto ho varím často.
# Aj keď toto jedlo nemám rád, je to jeho obľúbené, tak ho varím často.
# Aj keď toto jedlo nemám rada, je to jeho obľúbené, preto ho varím často.
#
# I never read horoscopes because they are lies made up by ordinary people.
# Nikdy nečítam horoskopy, pretože sú to lži, ktoré si vymysleli obyčajní ľudia.
# Nikdy som nečítal horoskopy, pretože sú to lži, ktoré si vymysleli obyčajní ľudia.
# Nikdy som nečítala horoskopy, pretože sú to lži, ktoré si vymysleli obyčajní ľudia.
#
# My friends appreciated that I looked good after the event.
# Moji priatelia ocenili, že po akcii vyzerám dobre.
# Moji priatelia ocenili, že som po akcii vyzeral dobre.
# Moji priatelia ocenili, že som po akcii vyzerala dobre.
#
# I could never hurt a loved one.
# Nikdy by som nedokázal ublížiť milovanej osobe.
# Nikdy by som nemohol ublížiť milovanej osobe.
# Nikdy som nemohla ublížiť milovanej osobe.
#
# Shopping for new clothes makes me happy.
# Nakupovanie nového oblečenia mi robí radosť.
# Nakupovanie nového oblečenia ma robí šťastným.
# Nakupovanie nového oblečenia ma robí šťastnou.
#
# My greatest strength is my concern for others, even though I am often seen as weak because of it.
# Mojou najväčšou silou je záujem o druhých, aj keď ma často považujú za slabého.
# Mojou najväčšou silou je záujem o druhých, aj keď som kvôli tomu často považovaný za slabého.
# Mojou najväčšou silou je záujem o druhých, aj keď ma často považujú za slabú.
#
# I don't like being stern, boring, and dull.
# Nemám rád, keď som prísny, nudný a nudný.
# Nerád som prísny, nudný a nudný.
# Nepáči sa mi byť prísna, nudná a nudná.
#
# The hockey players were in good shape.
# Hokejisti mali dobrú formu.
# Hokejisti boli v dobrej forme.
# Hokejisti boli v dobrej kondícii.
#
# I diligently sorted and recycled waste materials.
# Starostlivo triedim a recyklujem odpadové materiály.
# Usilovne som triedil a recykloval odpad.
# Usilovne som triedila a recyklovala odpadové materiály.
#
# I can be very annoyed when someone is chewing with their mouth open.
# Dokáže ma veľmi rozčuľovať, keď niekto žuje s otvorenými ústami.
# Dokážem byť veľmi naštvaný, keď niekto žuje s otvorenými ústami.
# Dokážem byť veľmi naštvaná, keď niekto žuje s otvorenými ústami.
#
# I was my duty to provide for them materially.
# Mojou povinnosťou bolo ich materiálne zabezpečiť.
# Bol som mojou povinnosťou zabezpečiť ich materiálne.
# Bola som mojou povinnosťou zabezpečiť ich materiálne.
#
# I enjoyed it when they took their clothes off.
# Bavilo ma, keď sa vyzliekali.
# Užil som si, keď sa vyzliekli.
# Bavilo ma, keď sa vyzliekli.
#
# I like being in charge.
# Páči sa mi byť vo vedení.
# Páči sa mi byť pod vedením.
# Páči sa mi, že som vo vedení.
#
# Translator:
# When I get calls from some surveys, I don’t have the heart to turn them down, so I always prefer to trick them into thinking I can’t talk.
# Keď mi zavolajú z nejakých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, že nemôžem hovoriť.
# Keď mi volajú z nejakých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, aby si mysleli, že nemôžem hovoriť.
# Keď mi volajú z nejakých prieskumov, nemám to srdce ich odmietnuť, takže ich vždy radšej oklamem, že nemôžem hovoriť.
#
# My friend is an excellent family provider.
# Môj priateľ je vynikajúci rodinný opatrovateľ.
# Môj priateľ je vynikajúci živiteľ rodiny.
# Môj priateľ je vynikajúci rodinný živiteľ.
#
# What I love about traveling is that I always bring back new friendship.
# Na cestovaní milujem to, že si z neho vždy prinášam nové priateľstvá.
# Na cestovaní milujem to, že si vždy priveziem nové priateľstvo.
# Na cestovaní sa mi páči, že si vždy priveziem nové priateľstvo.
#
# At first, it was hard for me to let my partner contribute financially to our family.
# Spočiatku bolo pre mňa ťažké nechať partnera finančne prispievať na našu rodinu.
# Spočiatku bolo pre mňa ťažké nechať partnerku finančne prispievať na našu rodinu.
# Zo začiatku bolo pre mňa ťažké nechať partnera finančne prispievať na našu rodinu.
#
# I always enjoyed martial arts.
# Bojové umenia ma vždy bavili.
# Vždy som mal rád bojové umenia.
# Vždy som mala rada bojové umenia.
#
# They preferred me because they assumed that I would be friendlier than other people.
# Dávali mi prednosť, pretože predpokladali, že budem priateľskejší ako ostatní ľudia.
# Dali mi prednosť, pretože predpokladali, že budem priateľskejší ako ostatní ľudia.
# Dali mi prednosť, pretože predpokladali, že budem priateľskejšia ako ostatní ľudia.
#
# I have an older neighbour with whom I agreed that we would go for a walk together at least once a week.
# Mám staršiu susedu, s ktorou sme sa dohodli, že aspoň raz do týždňa pôjdeme spolu na prechádzku.
# Mám staršiu susedu, s ktorou som sa dohodol, že aspoň raz do týždňa pôjdeme spolu na prechádzku.
# Mám staršiu susedu, s ktorou som sa dohodla, že aspoň raz týždenne pôjdeme spolu na prechádzku.
#
# I'm sad but I don't have any obvious reason.
# Som smutný, ale nemám žiadny zjavný dôvod.
# Som smutný, ale nemám žiadnu zjavnú príčinu.
# Som smutná, ale nemám žiaden zjavný dôvod.
#
# I've been told that I'm beautiful, because of my appearance and kind demeanor.
# Povedali mi, že som krásna, pretože mám pekný vzhľad a milé správanie.
# Povedali mi, že som krásny, pretože mám pekný vzhľad a milé správanie.
# Povedali mi, že som krásna vďaka svojmu vzhľadu a milému správaniu.
#
# I dreamt I slept with my favourite celebrity.
# Zdalo sa mi, že spím so svojou obľúbenou celebritou.
# Zdalo sa mi, že som spal so svojou obľúbenou celebritou.
# Zdalo sa mi, že som spala so svojou obľúbenou celebritou.
#
# I had to care about what happens with the children.
# Muselo mi záležať na tom, čo sa stane s deťmi.
# Musel som sa starať o to, čo sa stane s deťmi.
# Musela som sa starať o to, čo sa stane s deťmi.
#
# It made me happy to talk to someone.
# Potešilo ma, že sa môžem s niekým porozprávať.
# Potešilo ma, že som sa mohol s niekým porozprávať.
# Potešilo ma, že som sa mohla s niekým porozprávať.
#
# When dealing with family problems, I'm the problem-solver.
# Pri riešení rodinných problémov som riešiteľom problémov ja.
# Keď riešim rodinné problémy, som riešiteľom problémov ja.
# Pri riešení rodinných problémov som ja tá, ktorá rieši problémy.
#
# What type of shirts should I wear?
# Aký typ trička si mám obliecť?
# Aké košele si mám obliecť?
# Aké tričká si mám obliecť?
#
# I feel confident with my communication skills and with my ability to motivate others.
# Som presvedčený o svojich komunikačných schopnostiach a o svojej schopnosti motivovať ostatných.
# Cítim sa sebavedomo vďaka svojim komunikačným schopnostiam a schopnosti motivovať ostatných.
# Cítim sa sebavedomá vďaka svojim komunikačným schopnostiam a schopnosti motivovať ostatných.
#
# I'm always a winner in any race or competition.
# Vždy som víťazom akýchkoľvek pretekov alebo súťaže.
# Vždy som víťazom v akýchkoľvek pretekoch alebo súťaži.
# Vždy som víťazkou v akýchkoľvek pretekoch alebo súťaži.
#
# What should I do, so you finally be quiet?
# Čo mám urobiť, aby ste boli konečne ticho?
# Čo mám robiť, aby ste konečne boli ticho?
# Čo mám robiť, aby ste boli konečne ticho?
#
# Making you happy is making me happy.
# Keď si šťastný, som šťastná aj ja.
# Keď vás urobím šťastným, urobím šťastným aj seba.
# Keď vás urobím šťastnou, urobím šťastnou aj seba.
#
# I did not care that the swimming pool was for children only.
# Nevadilo mi, že bazén je určený len pre deti.
# Nezaujímalo ma, že bazén je len pre deti.
# Bolo mi jedno, že bazén je len pre deti.
#
# My high sex drive could make me susceptible to impulsive decisions when I was younger.
# Môj vysoký sexuálny apetít ma v mladosti mohol urobiť náchylným na impulzívne rozhodnutia.
# Môj vysoký sexuálny apetít mohol spôsobiť, že som bol v mladosti náchylný na impulzívne rozhodnutia.
# Môj vysoký sexuálny apetít mohol spôsobiť, že som bola v mladosti náchylná na impulzívne rozhodnutia.
#
# My partner left me alone with my kids and didn't told me what should I do with them
# Môj partner ma nechal s deťmi samú a nepovedal mi, čo s nimi mám robiť
# Moja partnerka ma nechala s deťmi samého a nepovedala mi, čo s nimi mám robiť.
# Môj partner ma nechal s deťmi samú a nepovedal mi, čo s nimi mám robiť.
#
# I am the manager of this company.
# Som manažérom tejto spoločnosti.
# Som manažér tejto spoločnosti.
# Som manažérka tejto spoločnosti.
#
# Don't worry about my credentials, I am a professional.
# O moje referencie sa nebojte, som profesionál.
# Nebojte sa o moje referencie, som profesionál.
# Nebojte sa o moje referencie, som profesionálka.
#
# As a leader, I'm expected to be in charge of difficult decisions.
# Od mňa ako od vedúceho sa očakáva, že budem mať na starosti ťažké rozhodnutia.
# Odo mňa ako od vedúceho sa očakáva, že budem mať na starosti ťažké rozhodnutia.
# Odo mňa ako od vedúcej pracovníčky sa očakáva, že budem mať na starosti ťažké rozhodnutia.
#
# You knew almost everybody in that club!
# V tom klube si poznal takmer každého!
# V tom klube ste poznali takmer každého!
# V tom klube ste poznali takmer všetkých!
#
# I came up with swimming accross the river in the middle of a storm.
# Napadlo mi plávať cez rieku uprostred búrky.
# Prišiel som s tým, že som uprostred búrky preplával rieku.
# Prišla som na to, že som uprostred búrky preplávala rieku.
#
# I am a stand-up comedian.
# Som stand-up komik.
# Som komik.
# Som stand-up komička.
#
# I dreamt about sleeping with them tonight.
# Dnes v noci sa mi snívalo o tom, ako s nimi spím.
# Dnes sa mi snívalo, že s nimi spím.
# Dnes sa mi snívalo o tom, že s nimi spím.
#
# I'm not sure if you are right for that position because it contains a lot of stress and pressure.
# Nie som si istý, či ste na túto pozíciu vhodný, pretože je v nej veľa stresu a tlaku.
# Nie som si istý, či sa na túto pozíciu hodíte, pretože je v nej veľa stresu a tlaku.
# Nie som si istá, či sa na túto pozíciu hodíte, pretože je v nej veľa stresu a tlaku.
#
# I love receiving other people's approvals.
# Rád prijímam súhlasy iných ľudí.
# Milujem, keď mi iní ľudia dávajú súhlas.
# Milujem, keď ma iní ľudia schvaľujú.
#
# I always enjoyed leading others.
# Vždy ma bavilo viesť ostatných.
# Vždy som rád viedol iných.
# Vždy som rada viedla iných.
#
# I am confident in myself.
# Verím si.
# Som si istý sám sebou.
# Som si istá sama sebou.
#
# I like it when someone compliments how I look.
# Páči sa mi, keď mi niekto pochváli, ako vyzerám.
# Mám rád, keď mi niekto pochváli, ako vyzerám.
# Mám rada, keď mi niekto pochváli, ako vyzerám.
#
# My mom told me that it doesn't matter if I'm not the most clever in the school as long as my hair shines the brightest.
# Mama mi povedala, že nezáleží na tom, či nie som najchytrejšia v škole, ak moje vlasy žiaria najjasnejšie.
# Moja mama mi povedala, že nezáleží na tom, či nie som najchytrejší v škole, ak moje vlasy žiaria najjasnejšie.
# Moja mama mi povedala, že nezáleží na tom, či nie som najchytrejšia v škole, ak moje vlasy žiaria najjasnejšie.
#
# I like it when take care of my appearance and someone appreciates it.
# Páči sa mi, keď sa starám o svoj vzhľad a niekto to ocení.
# Mám rád, keď sa starám o svoj vzhľad a niekto to ocení.
# Mám rada, keď sa starám o svoj vzhľad a niekto to ocení.
#
# I received compliments from friends and family on my stunning appearance for a special occasion.
# Priatelia a rodina ma pochválili za môj úžasný vzhľad pri špeciálnej príležitosti.
# Priatelia a rodina mi pri špeciálnej príležitosti pochválili môj úžasný vzhľad.
# Priatelia a rodina mi pri špeciálnej príležitosti zložili poklonu za môj úžasný vzhľad.
#
# I've made it a tradition that every Christmas I buy a gift at one of the benefit stores.
# Stalo sa mojou tradíciou, že každé Vianoce kupujem darček v jednom z obchodov s výhodami.
# Zaviedol som si tradíciu, že každé Vianoce kupujem darček v niektorom z obchodov s benefitmi.
# Zaviedla som si tradíciu, že každé Vianoce kupujem darček v niektorom z obchodov s benefitmi.
#
# Being the leader meant shouldering the responsibility of motivating and inspiring my team members, helping them unlock their full potential.
# Byť lídrom znamenalo prevziať zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomôcť im naplno rozvinúť ich potenciál.
# Byť lídrom znamená niesť zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomáhať im naplno rozvinúť ich potenciál.
# Byť vedúcou znamenalo prevziať zodpovednosť za motiváciu a inšpiráciu členov môjho tímu a pomôcť im naplno rozvinúť ich potenciál.
#
# Taking care of my family financially makes me happy.
# Finančná starostlivosť o rodinu ma robí šťastnou.
# Keď sa finančne starám o svoju rodinu, som šťastný.
# Keď sa finančne starám o svoju rodinu, som šťastná.
#
# I'm naturally better at technical subjects.
# Prirodzene som lepší v technických predmetoch.
# Som prirodzene lepší v technických predmetoch.
# Som prirodzene lepšia v technických predmetoch.
#
# Part of the interview for a flight attendant was an actual excercise to see if I could lift the heavy suitaceses.
# Súčasťou pohovoru na miesto letušky bol aj skutočný nácvik, či dokážem zdvihnúť ťažké obleky.
# Súčasťou pohovoru na pozíciu letušky bolo skutočné cvičenie, aby sa zistilo, či dokážem zdvihnúť ťažké obleky.
# Súčasťou pohovoru na miesto letušky bolo skutočné cvičenie, aby sa zistilo, či dokážem zdvihnúť ťažké obleky.
#
# I am extremely discerning when it comes to choosing a sexual partner.
# Pri výbere sexuálneho partnera som veľmi náročný.
# Som veľmi náročný, pokiaľ ide o výber sexuálnej partnerky.
# Pri výbere sexuálneho partnera som veľmi náročná.
#
# I am very good at pretending that I am fine.
# Veľmi dobre sa mi darí predstierať, že som v poriadku.
# Som veľmi dobrý v predstieraní, že som v poriadku.
# Som veľmi dobrá v predstieraní, že som v poriadku.
#
# People think of me as a wimp just because I’m good to others.
# Ľudia si o mne myslia, že som slaboch len preto, že som k ostatným dobrý.
# Ľudia ma považujú za slabocha len preto, že som dobrý k ostatným.
# Ľudia si o mne myslia, že som slaboch len preto, že som dobrá k ostatným.
#
# I have always enjoyed teaching others.
# Vždy ma bavilo učiť ostatných.
# Vždy som rád učil iných.
# Vždy som rada učila iných.
#
# I love creating the warmth of home.
# Milujem vytvárať teplo domova.
# Rád vytváram teplo domova.
# Rada vytváram teplo domova.
#
# When I enter the door to my work, I immediately become competitive.
# Keď vstúpim do svojej práce, okamžite začnem súťažiť.
# Keď vstúpim do práce, okamžite sa stanem súťaživým.
# Keď vstúpim do práce, okamžite sa stanem súťaživou.
#
# Being strong is crucial in self-defence.
# Pri sebaobrane je veľmi dôležité byť silný.
# Byť silný je pri sebaobrane veľmi dôležité.
# Pri sebaobrane je rozhodujúce byť silný.
#
# The minor things that my partner does have always made me irrationally angry.
# Drobnosti, ktoré robí môj partner, ma vždy iracionálne rozčuľovali.
# Drobnosti, ktoré robí moja partnerka, ma vždy iracionálne rozčuľovali.
# Drobnosti, ktoré môj partner robí, ma vždy iracionálne rozčuľovali.
#
# I’m the only one who does anything in this household.
# Som jediný, kto v tejto domácnosti niečo robí.
# Ja som jediný, kto v tejto domácnosti niečo robí.
# Ja som jediná, kto v tejto domácnosti niečo robí.
#
# You shouldn't be crying.
# Nemali by ste plakať.
# Nemal by si plakať.
# Nemala by si plakať.
#
# I didn't spend a lot of time preparing, because I have a pretty face.
# Prípravám som nevenovala veľa času, pretože mám peknú tvár.
# Nestrávil som veľa času prípravami, pretože mám peknú tvár.
# Nestrávila som veľa času prípravami, pretože mám peknú tvár.
#
# It’s hard for me to be new in the city because I don’t have any friends here.
# Je pre mňa ťažké byť v meste nováčikom, pretože tu nemám žiadnych priateľov.
# Je pre mňa ťažké byť v meste nový, pretože tu nemám žiadnych priateľov.
# Je pre mňa ťažké byť nová v meste, pretože tu nemám žiadnych priateľov.
#
# I often feel stressed about making enough money for the family.
# Často som v strese z toho, že musím zarobiť dostatok peňazí pre rodinu.
# Často sa cítim vystresovaný z toho, či zarobím dosť peňazí pre rodinu.
# Často sa cítim vystresovaná z toho, či zarobím dosť peňazí pre rodinu.
#
# I like having an extra job.
# Páči sa mi, že mám prácu navyše.
# Mám rád prácu navyše.
# Mám rada prácu navyše.
#
# My colleague is more professional than I am ever going to be.
# Môj kolega je väčší profesionál, ako ja kedy budem.
# Môj kolega je väčší profesionál, ako budem ja.
# Môj kolega je väčší profesionál, než ja kedy budem.
#
# I'm sexually attracted to my colleague.
# Môj kolega ma sexuálne priťahuje.
# Sexuálne ma priťahuje moja kolegyňa.
# Sexuálne ma priťahuje môj kolega.
#
# I don't keep my money in a safe, because robbers don't scare me.
# Peniaze nemám v trezore, pretože ma zlodeji nedesia.
# Peniaze si nenechávam v trezore, pretože ma zlodeji nedesia.
# Peniaze si neschovávam v trezore, pretože ma zlodeji nedesia.
#
# I am the breadwinner of this family.
# Som živiteľkou tejto rodiny.
# Ja som živiteľom tejto rodiny.
# Ja som živiteľkou tejto rodiny.
#
# If you weren't with me, god knows how it'd end.
# Keby si nebol so mnou, boh vie, ako by sa to skončilo.
# Keby si nebol so mnou, boh vie, ako by to skončilo.
# Keby si nebol so mnou, bohvie, ako by to skončilo.
#
# Finally the beauty catalogue that I ordered has arrived.
# Konečne mi prišiel objednaný katalóg krásy.
# Konečne prišiel katalóg krásy, ktorý som si objednal.
# Konečne prišiel katalóg krásy, ktorý som si objednala.
#
# When becoming a leader, the key aspect was to be capable of managing complex situations.
# Kľúčovým aspektom, keď sa stal lídrom, bola schopnosť zvládať zložité situácie.
# Keď som sa stal lídrom, kľúčovým aspektom bolo vedieť zvládať zložité situácie.
# Keď som sa stala vedúcou osobnosťou, kľúčovým aspektom bolo, aby som dokázala zvládať zložité situácie.
#
# I am the manager of this bank.
# Som manažér tejto banky.
# Ja som riaditeľ tejto banky.
# Ja som riaditeľka tejto banky.
#
# I was enjoying leading others.
# Bavilo ma viesť ostatných.
# Tešilo ma, že som viedol ostatných.
# Tešila som sa, že môžem viesť ostatných.
#
# I managed to climb that old shaky ladder with no hesitation.
# Na ten starý vratký rebrík sa mi podarilo vyliezť bez zaváhania.
# Dokázal som vyliezť na ten starý vratký rebrík bez zaváhania.
# Dokázala som vyliezť na ten starý vratký rebrík bez zaváhania.
#
# You should learn how to defend yourself.
# Mali by ste sa naučiť, ako sa brániť.
# Mal by si sa naučiť brániť.
# Mal by si sa naučiť, ako sa brániť.
#
# Why did you always need to prove something?
# Prečo ste vždy museli niečo dokazovať?
# Prečo musíš stále niečo dokazovať?
# Prečo si vždy musel niečo dokazovať?
#
# They were surprised to see that I could stand up for myself.
# Boli prekvapení, keď videli, že sa dokážem postaviť na vlastné nohy.
# Boli prekvapení, keď videli, že sa dokážem postaviť sám za seba.
# Boli prekvapení, keď videli, že sa dokážem postaviť sama za seba.
#
# I could never hurt a loved one.
# Nikdy by som nedokázal ublížiť milovanej osobe.
# Nikdy by som nemohol ublížiť milovanej osobe.
# Nikdy by som nemohla ublížiť milovanej osobe.
#
# I found it challenging to perform simple tasks like opening jars or lifting objects due to my physical weakness.
# Kvôli mojej fyzickej slabosti bolo pre mňa náročné vykonávať jednoduché úlohy, ako je otváranie pohárov alebo zdvíhanie predmetov.
# Kvôli svojej fyzickej slabosti som mal problém vykonávať jednoduché úlohy, ako je otváranie pohárov alebo zdvíhanie predmetov.
# Kvôli svojej fyzickej slabosti som mala problém vykonávať jednoduché úlohy, ako je otváranie pohárov alebo zdvíhanie predmetov.
#
# We were too scared to go outside by ourselves so we stayed at home.
# Boli sme príliš vystrašení, aby sme išli sami von, a tak sme zostali doma.
# Báli sme sa ísť sami von, tak sme zostali doma.
# Boli sme príliš vystrašení, aby sme sami vyšli von, tak sme zostali doma.
#
# I liked when my partner complimented my appearance.
# Páčilo sa mi, keď mi partner pochválil môj vzhľad.
# Páčilo sa mi, keď mi partnerka pochválila môj vzhľad.
# Páčilo sa mi, keď môj partner pochválil môj vzhľad.
#
# Taking care of my children is the least I can do for my family.
# Starostlivosť o deti je to najmenej, čo môžem pre svoju rodinu urobiť.
# Postarať sa o svoje deti je to najmenej, čo môžem urobiť pre svoju rodinu.
# Postarať sa o svoje deti je to najmenej, čo môžem pre svoju rodinu urobiť.
#
# Translator:
# I order groceries from home so I don't have to carry those heavy bags across town.
# Objednám si potraviny z domu, takže nemusím nosiť tie ťažké tašky cez mesto.
# Objednám si potraviny z domu, aby som nemusel nosiť tie ťažké tašky cez mesto.
# Objednám si potraviny z domu, aby som nemusela nosiť tie ťažké tašky cez mesto.
#
# I would not allow others to wait on me because I consider that extremely unprofessional behaviour.
# Nedovolím ostatným, aby na mňa čakali, pretože to považujem za mimoriadne neprofesionálne správanie.
# Nedovolím ostatným, aby na mňa čakali, pretože považujem toto mimoriadne neprofesionálne správanie.
# Nedovolila by som ostatným, aby na mňa čakali, pretože považujem to za mimoriadne neprofesionálne správanie.
#
# I'm sad that you hurt me, because I like you.
# Je mi ľúto, že si mi ublížil, pretože ťa mám rád.
# Som smutný, že si mi ublížil, pretože ťa mám rád.
# Som smutná, že si mi ublížil, pretože ťa mám rád.
#
# I put extra effort into making my hair look good today.
# Vynakladám ďalšie úsilie na to, aby moje vlasy vyzerali dobre.
# Vynaložil som ďalšie úsilie na to, aby moje vlasy dnes vyzerali dobre.
# Vynaložila som väčšie úsilie na to, aby moje vlasy vyzerali dobre dnes.
#
# We're going to play a knowledge game, you shouldn't be playing.
# Budeme hrať vedomostnú hru, nemali by ste hrať.
# Budeme hrať hru na vedomosti, nemali by ste hrať.
# Budeme hrať znalostnú hru, nemali by ste hrať.
#
# I was feeling honoured to stay at home with a kids.
# Bolo mi cťou zostať doma s deťmi.
# Bol som poctený zostať doma s deťmi.
# Bola som poctená zostať doma s deťmi.
#
# I did not mind that the supervisor took all the credit for my work.
# Nevadí mi, že vedúci vzal všetku zásluhu na mojej práci.
# Nevadí mi, že nadriadený vzal všetku zásluhu na mojej práci.
# Nevadí mi, že supervízor vzal všetku zásluhu na mojej práci.
#
# They said that I'm good at cleaning and it made me so happy.
# Povedali, že som dobrý v upratovaní a to ma veľmi potešilo.
# Povedali, že som dobrý v upratovaní a urobilo ma to tak šťastným.
# Povedali, že som dobrá v upratovaní a to ma veľmi potešilo.
#
# You talked way too much with them.
# Rozprávali ste sa s nimi príliš veľa.
# Rozprával si sa s nimi príliš veľa.
# Príliš ste s nimi hovorili.
#
# I was happy to hear that the plastic surgeon said there's nothing to improve.
# Bol som rád, keď som počul, že plastický chirurg povedal, že nie je čo zlepšovať.
# Bol som rád, že plastický chirurg povedal, že nie je čo zlepšovať.
# S radosťou som počula, že plastický chirurg povedal, že nie je čo zlepšovať.
#
# I'm always a winner in any race or competition.
# Vždy som víťaz v každom závode alebo súťaži.
# Vždy som víťaz v každom preteku alebo súťaži.
# Vždy som víťazom v každom závode alebo súťaži.
#
# I like to have responsibility for large projects.
# Mám rád zodpovednosť za veľké projekty.
# Rád nesiem zodpovednosť za veľké projekty.
# Rád by som mal zodpovednosť za veľké projekty.
#
# I have a lot of porn saved in my computer.
# Mám veľa porno uložených v počítači.
# Mám v počítači uložené veľa porna.
# V počítači mám uložených veľa pornografie.
#
# I like to solve problems and look for creative solutions.
# Rád riešime problémy a hľadám kreatívne riešenia.
# Rád rieším problémy a hľadám kreatívne riešenia.
# Rád riešim problémy a hľadám kreatívne riešenia.
#
# I like to drive fast in my sports car.
# Rád jazdím rýchlo v športovom aute.
# Rád jazdím rýchlo vo svojom športovom aute.
# Rád jazdím rýchlo v mojom športovom aute.
#
# I am able to deal successfully with hard situations.
# Dokážu úspešne zvládnuť ťažké situácie.
# Som schopný úspešne zvládnuť ťažké situácie.
# Som schopná úspešne zvládnuť ťažké situácie.
#
# As a leader, I'm expected to be in charge of difficult decisions.
# Ako líder sa od mňa očakáva, že budem mať na starosti ťažké rozhodnutia.
# Očakáva sa, že ako vodca budem mať na starosti ťažké rozhodnutia.
# Ako vodca sa očakáva, že budem mať na starosti ťažké rozhodnutia.
#
# I am a journalist, more specifically, the editor-in-chief of the local newspaper.
# Som novinár, konkrétnejšie šéfredaktor miestnych novín.
# Som novinár, presnejšie šéfredaktor miestnych novín.
# Som novinárka, konkrétnejšie šéfredaktorka miestnych novín.
#
# The only one I can really rely on is myself.
# Jediný, na koho sa môžem skutočne spoľahnúť, som ja sám.
# Jediný, na koho sa môžem skutočne spoľahnúť, som sám.
# Jediný, na koho sa môžem skutočne spoľahnúť, som ja.
#
# I'd rather live in a mess than have to clean up my room.
# Radšej budem žiť v neporiadku, ako upratovať izbu.
# Radšej by som žil v neporiadku, ako by som musel upratovať izbu.
# Radšej by som žila v neporiadku, než aby som si musela upratať izbu.
#
# What do you think, am I likable?
# Čo si myslíte, som sympatný?
# Čo si myslíš, som sympatická?
# Čo si myslíte, som sympatická?
#
# People often come to me for advice because they know I am the best.
# Ľudia často prichádzajú za mnou pre radu, pretože vedia, že som najlepší.
# Ľudia za mnou často prichádzajú pre radu, pretože vedia, že som najlepší.
# Ľudia za mnou často prichádzajú o radu, pretože vedia, že som najlepší.
#
# I like to party every Saturday.
# Mám rada párty každú sobotu.
# Rád sa každú sobotu zúčastňujem párty.
# Páči sa mi každú sobotu párty.
#
# I'm naturally better at technical subjects.
# Prirodzene som lepší v technických predmetoch.
# V technických predmetoch som prirodzene lepší.
# V technických predmetoch som prirodzene lepšia.
#
# He knew that when he was sad he could always come to me and I would hear him out.
# Vedel, že keď bol smutný, vždy môže prísť ku mne a ja ho vypočujem.
# Vedel, že keď je smutný, môže vždy prísť ku mne a ja ho vypočujem.
# Vedel, že keď je smutný, vždy môže prísť ku mne a ja ho vypočujem.
#
# They say I’m insensitive, but I call it sensible.
# Hovorí sa, že som necitlivý, ale nazývam to rozumným.
# Hovoria, že som necitlivý, ale ja to nazývam rozumným.
# Hovoria, že som necitlivá, ale ja to nazývam rozumným.
#
# I wouldn't let anyone dictate what I should do.
# Nedovolím nikomu diktovať, čo mám robiť.
# Nenechal by som nikomu diktovať, čo mám robiť.
# Nedovolila by som nikomu diktovať, čo mám robiť.
#
# I will gladly take your bag.
# Radi si vezmem tvoju tašku.
# Rád vezmem tvoju tašku.
# S radosťou vezmem tvoju tašku.
#
# Help me with my luggage, you're stronger than me.
# Pomôžte mi s batožinou, ste silnejší ako ja.
# Pomôž mi s mojou batožinou, si silnejší ako ja.
# Pomôžte mi s mojou batožinou, ste silnejší ako ja.
#
# When I have to go to a work meeting, I immediately get all sweaty from stress.
# Keď musím ísť na pracovné stretnutie, okamžite sa spotim zo stresu.
# Keď musím ísť na pracovné stretnutie, okamžite sa spotím zo stresu.
# Keď musím ísť na pracovné stretnutie, okamžite som sa spotil zo stresu.
#
# I actively engaged with stakeholders.
# Aktívne spolupracujem so zainteresovanými stranami.
# Aktívne som sa angažoval so zainteresovanými stranami.
# Aktívne som sa angažovala so zainteresovanými stranami.
#
# I couldn't understand why would you need 20 pairs of shoes.
# Nechápem, prečo by ste potrebovali 20 párov topánok.
# Nechápal som, prečo by ste potrebovali 20 párov topánok.
# Nemohla som pochopiť, prečo by ste potrebovali 20 párov topánok.
#
# They always tell me I work a lot, but that’s just the way I am.
# Vždy mi hovoria, že veľa pracujem, ale to je presne to, čo som.
# Vždy mi hovoria, že veľa pracujem, ale to je presne taký, aký som.
# Vždy mi hovoria, že veľa pracujem, ale tak som.
#
# It was a tough choice, but I am confident that it was right.
# Bola to ťažká voľba, ale verím, že to bolo správne.
# Bola to ťažká voľba, ale som presvedčený, že to bolo správne.
# Bola to ťažká voľba, ale som presvedčená, že to bolo správne.
#
# I could totally imagine myself in their position.
# Dokážem si predstaviť samého seba v ich pozícii.
# Dokázal som si úplne predstaviť seba v ich pozícii.
# Dokázala som si úplne predstaviť seba v ich pozícii.
#
# They were freaking out at that concert.
# Na tom koncerte sa zľakli.
# Na tom koncerte sa vystrašili.
# Na tom koncerte boli vystrašení.
#
# I'm sexually attracted to my colleague.
# Sexuálne ma priťahuje môj kolega.
# Som sexuálne priťahovaný k svojmu kolegovi.
# Som sexuálne priťahovaná k môjmu kolegovi.
#
# I like to be in charge.
# Páči sa mi, že mám na starosti.
# Rád mám na starosti.
# Rád by som mal na starosti.
#
# I feel confident most of the time so it came naturally to me to be a leader.
# Väčšinu času sa cítim sebavedomo, takže mi prišlo prirodzené byť lídrom.
# Väčšinu času sa cítim sebavedomý, takže mi prišlo prirodzené byť vodcom.
# Väčšinu času sa cítim sebavedomá, takže mi prišlo prirodzené byť vodcom.
#
# I don't keep my money in a safe, because robbers don't scare me.
# Nechávam svoje peniaze v trezore, pretože lupiči ma nevystraší.
# Nemám svoje peniaze v trezore, pretože lupiči ma nevystraší.
# Nechovám svoje peniaze v trezore, pretože lupiči ma nevystrašia.
#
# Since I've been doing this sport, I'm much more balanced.
# Odkedy sa venujem tomuto športu, som oveľa vyváženejší.
# Odkedy robím tento šport, som oveľa vyrovnanejší.
# Odkedy robím tento šport, som oveľa vyrovnanejšia.
#
# I am able to see the big picture of where the organisation is heading.
# Vidím celkový obraz toho, kam organizácia smeruje.
# Som schopný vidieť celkový obraz toho, kam organizácia smeruje.
# Som schopná vidieť celkový obraz toho, kam organizácia smeruje.
#
# I'm very competitive when it comes to promotions and performance in the workplace.
# Som veľmi konkurencieschopný, pokiaľ ide o propagáciu a výkon na pracovisku.
# Som veľmi konkurencieschopný, pokiaľ ide o povýšenie a výkon na pracovisku.
# Som veľmi konkurencieschopná, pokiaľ ide o povýšenie a výkon na pracovisku.
#
# Don't go there alone, it can be dangerous.
# Nechoďte tam sami, môže to byť nebezpečné.
# Nechoď tam sám, môže to byť nebezpečné.
# Nechoď tam sama, môže to byť nebezpečné.
#
# I think my co-worker is an excellent leader.
# Myslím si, že môj spolupracovník je vynikajúci líder.
# Myslím si, že môj spolupracovník je vynikajúci vodca.
# Myslím, že môj spolupracovník je vynikajúci vodca.
#
# I like to talk so much that I do it with animals too.
# Rád sa rozprávam natoľko, že to robím aj so zvieratami.
# Rád hovorím tak veľmi, že to robím aj so zvieratami.
# Rád hovorím toľko, že to robím aj so zvieratami.
#
# I've raised my kids to be orderly from a young age.
# Vychovávam svoje deti, aby boli poriadne od mladého veku.
# Vychovával som svoje deti, aby boli usporiadané už od mladého veku.
# Vychovávala som svoje deti, aby boli usporiadané už od mladého veku.
#
# Did you see that body?!
# Videli ste to telo?
# Videl si to telo?!
# Videli ste to telo?!
#
# I preferred travelling in groups.
# Preferujem cestovanie v skupinách.
# Radšej som cestoval v skupinách.
# Radšej som cestovala v skupinách.
#
# I offered the best services in the entire town.
# Ponúkame najlepšie služby v celom meste.
# Ponúkol som najlepšie služby v celom meste.
# Ponúkla som najlepšie služby v celom meste.
#
# My greatest strength is my concern for others, even though I am often seen as weak because of it.
# Mojou najväčšou silou je moja starosť o ostatných, aj keď som kvôli tomu často považovaný za slabého.
# Mojou najväčšou silou je moja starosť o druhých, aj keď som kvôli tomu často považovaný za slabého.
# Mojou najväčšou silou je moja starosť o druhých, aj keď som kvôli tomu často považovaná za slabú.
#
# It was easy for me to make friends on the first day of university.
# Bolo pre mňa ľahké nájsť si priateľov v prvý deň na univerzite.
# Bolo pre mňa ľahké nájsť si priateľov v prvý deň univerzity.
# Bolo pre mňa ľahké spriateliť sa v prvý deň univerzity.
#
# I enjoyed it when they took their clothes off.
# Páčilo sa mi, keď sa vyzliekli.
# Užíval som si to, keď sa vyzliekli.
# Užívala som si to, keď sa vyzliekli.
#
# I like the feeling of providing for others.
# Páči sa mi pocit, že sa poskytol iným.
# Páči sa mi pocit zabezpečenia druhých.
# Páči sa mi pocit, že sa postará o ostatných.
#
# I like to have my coffee on the table at 9.00 AM every day, can you do it?
# Rád si dám kávu na stole každý deň o 9.00 hod., môžete to urobiť?
# Rád si dám kávu na stole každý deň o 9.00 hod., môžeš to urobiť?
# Páči sa mi, keď mám kávu na stole každý deň o 9.00 hod., môžete to urobiť?
#
# I never let anybody be dominant when having sex with me.
# Nikdy nedovolím, aby bol niekto dominantný, keď so mnou má sex.
# Nikdy som nenechal nikoho dominovať, keď so mnou má sex.
# Nikdy som nedovolila, aby bol niekto dominantný, keď so mnou má sex.
#
# 215

# %%
x = 0

logging.getLogger().setLevel(logging.WARNING)
for t in (google_translate, deepl, amazon_translate):
    print('Translator:')
    for sentence in sentences:
        # heuristic_verbs(sentence, t)
        d, m, f = sentence_variants(sentence, t)
        if heuristic(sentence, t) is None and m == f:
            x += 1
            print(sentence)
            for s in sentence_variants(sentence, t):
                print(s)
            print()
print(x)
# Out:
# Translator:
# I try avoid confrontation because I tend to cry when I am under pressure.
# Snažím sa vyhýbať konfrontácii, pretože mám tendenciu plakať, keď som pod tlakom.
# Snažím sa vyhýbať konfrontácii, pretože mám tendenciu plakať, keď som pod tlakom.
# Snažím sa vyhýbať konfrontácii, pretože mám tendenciu plakať, keď som pod tlakom.
#
# I've been told that I'm caring and that I have nurturing personality.
# Bolo mi povedané, že sa o mňa starám a že mám výchovnú osobnosť.
# Bolo mi povedané, že sa o mňa starám a že mám výchovnú osobnosť.
# Bolo mi povedané, že sa o mňa starám a že mám výchovnú osobnosť.
#
# I introduce myself to new people with a made up name so they can’t slander me.
# Predstavujem sa novým ľuďom s vymysleným menom, aby ma nemohli ohovárať.
# Predstavujem sa novým ľuďom s vymysleným menom, aby ma nemohli ohovárať.
# Predstavujem sa novým ľuďom s vymysleným menom, aby ma nemohli ohovárať.
#
# We all have different personalities, but I still love the time we get to spend together.
# Všetci máme rôzne povahy, ale aj tak milujem čas, ktorý spolu trávime.
# Všetci máme rôzne povahy, ale stále milujem čas, ktorý spolu trávime.
# Všetci máme rôzne povahy, ale stále milujem čas, ktorý spolu trávime.
#
# Problem-solving was my biggest strength.
# Riešenie problémov bolo mojou najväčšou silou.
# Riešenie problémov bolo mojou najväčšou silou.
# Riešenie problémov bolo mojou najväčšou silou.
#
# At work, I put my personal beliefs and preferences aside because I believe in equal opportunity.
# V práci dávam svoje osobné presvedčenia a preferencie bokom, pretože verím v rovnaké príležitosti.
# V práci dávam svoje osobné presvedčenia a preferencie bokom, pretože verím v rovnaké príležitosti.
# V práci dávam svoje osobné presvedčenia a preferencie bokom, pretože verím v rovnaké príležitosti.
#
# I am a leader.
# Som vodca.
# Som vodca.
# Som vodca.
#
# I feel like they are watching every move I make.
# Mám pocit, že sledujú každý môj pohyb.
# Mám pocit, že sledujú každý môj pohyb.
# Mám pocit, že sledujú každý môj pohyb.
#
# It was right of me to obey my husband.
# Bolo odo mňa správne poslúchnuť svojho manžela.
# Bolo odo mňa správne poslúchnuť svojho manžela.
# Bolo odo mňa správne poslúchnuť svojho manžela.
#
# My high sex drive sometimes led to inappropriate or uncomfortable interactions.
# Moja vysoká sexuálna túžba niekedy viedla k nevhodným alebo nepríjemným interakciám.
# Moja vysoká sexuálna túžba niekedy viedla k nevhodným alebo nepríjemným interakciám.
# Moja vysoká sexuálna túžba niekedy viedla k nevhodným alebo nepríjemným interakciám.
#
# My friend is an excellent family provider.
# Môj priateľ je skvelým živiteľom rodiny.
# Môj priateľ je vynikajúcim živiteľom rodiny.
# Môj priateľ je vynikajúcim živiteľom rodiny.
#
# I didn't mind having sex with many people in a short time.
# Nevadilo mi mať sex s mnohými ľuďmi v krátkom čase.
# Nevadilo mi mať sex s mnohými ľuďmi v krátkom čase.
# Nevadilo mi mať sex s mnohými ľuďmi v krátkom čase.
#
# I join group activities and discussions very often and I like it.
# Veľmi často sa zapájam do skupinových aktivít a diskusií a mám to rád.
# Veľmi často sa zapájam do skupinových aktivít a diskusií a páči sa mi to.
# Veľmi často sa zapájam do skupinových aktivít a diskusií a páči sa mi to.
#
# What I love about traveling is that I always bring back new friendship.
# Na cestovaní milujem to, že vždy prinášam nové priateľstvá.
# Na cestovaní milujem to, že vždy prinášam nové priateľstvá.
# Na cestovaní milujem to, že vždy prinášam nové priateľstvá.
#
# My friend is really musculus.
# Môj priateľ je naozaj svalnatý.
# Môj priateľ je naozaj svalnatý.
# Môj priateľ je naozaj svalnatý.
#
# I don’t like being told how to do my job.
# Nemám rád, keď mi niekto hovorí, ako mám robiť svoju prácu.
# Nepáči sa mi, že mi hovoria, ako mám robiť svoju prácu.
# Nepáči sa mi, že mi hovoria, ako mám robiť svoju prácu.
#
# I was not affected by my emotions at all.
# Vôbec ma neovplyvnili moje emócie.
# Vôbec ma neovplyvnili moje emócie.
# Vôbec ma neovplyvnili moje emócie.
#
# Every time I get up, I have to open the window and make my bed.
# Vždy, keď vstanem, musím otvoriť okno a ustlať si posteľ.
# Vždy, keď vstanem, musím otvoriť okno a ustlať si posteľ.
# Vždy, keď vstanem, musím otvoriť okno a ustlať si posteľ.
#
# I can not lift this, it is too heavy.
# Nemôžem to zdvihnúť, je to príliš ťažké.
# Nemôžem to zdvihnúť, je to príliš ťažké.
# Nemôžem to zdvihnúť, je to príliš ťažké.
#
# That film made me cry like a baby.
# Ten film ma rozplakal ako dieťa.
# Ten film ma rozplakal ako dieťa.
# Ten film ma rozplakal ako dieťa.
#
# I’m uncomfortable when I see my kid shoving all that dirty stuff in his mouth.
# Je mi nepríjemné, keď vidím, ako si moje dieťa strká všetky tie špinavé veci do úst.
# Je mi nepríjemné, keď vidím, ako si moje dieťa strká všetky tie špinavé veci do úst.
# Je mi nepríjemné, keď vidím, ako si moje dieťa strká všetky tie špinavé veci do úst.
#
# At first, it was hard for me to let my partner contribute financially to our family.
# Spočiatku bolo pre mňa ťažké nechať partnera finančne prispievať do našej rodiny.
# Spočiatku bolo pre mňa ťažké nechať svojho partnera finančne prispievať do našej rodiny.
# Spočiatku bolo pre mňa ťažké nechať svojho partnera finančne prispievať do našej rodiny.
#
# My friend could not be without sex for longer than two weeks.
# Môj priateľ nemohol byť bez sexu dlhšie ako dva týždne.
# Môj priateľ nemohol byť bez sexu dlhšie ako dva týždne.
# Môj priateľ nemohol byť bez sexu dlhšie ako dva týždne.
#
# My co-worker we always be childish.
# Môj spolupracovník sme vždy detinskí.
# Môj spolupracovník, vždy sme detinskí.
# Môj spolupracovník, vždy sme detinskí.
#
# I always enjoyed running.
# Beh ma vždy bavil.
# Vždy ma bavilo behať.
# Vždy ma bavilo behať.
#
# I always enjoyed martial arts.
# Vždy ma bavili bojové umenia.
# Vždy ma bavili bojové umenia.
# Vždy ma bavili bojové umenia.
#
# My communication skills make me the best leader in the whole company.
# Moje komunikačné schopnosti zo mňa robia najlepšieho lídra v celej spoločnosti.
# Moje komunikačné schopnosti zo mňa robia najlepšieho lídra v celej spoločnosti.
# Moje komunikačné schopnosti zo mňa robia najlepšieho lídra v celej spoločnosti.
#
# If I don't clean my ears after a shower, I'm uncomfortable.
# Ak si po sprche nevyčistím uši, je mi to nepríjemné.
# Ak si po sprche nevyčistím uši, je mi to nepríjemné.
# Ak si po sprche nevyčistím uši, je mi to nepríjemné.
#
# We're going to play a knowledge game, you shouldn't be playing.
# Ideme hrať vedomostnú hru, nemali by ste sa hrať.
# Budeme hrať vedomostnú hru, nemali by ste sa hrať.
# Budeme hrať vedomostnú hru, nemali by ste sa hrať.
#
# You provoked me by the way you were dressed.
# Provokoval si ma tým, ako si bol oblečený.
# Provokoval si ma tým, ako si bol oblečený.
# Provokoval si ma tým, ako si bol oblečený.
#
# They said, that I was the best listener in the whole world.
# Povedali, že som najlepší poslucháč na celom svete.
# Povedali, že som najlepší poslucháč na celom svete.
# Povedali, že som najlepší poslucháč na celom svete.
#
# In my company, I try to be an objective and less emotional boss.
# Vo svojej firme sa snažím byť objektívny a menej emotívny šéf.
# V mojej spoločnosti sa snažím byť objektívnym a menej emocionálnym šéfom.
# V mojej spoločnosti sa snažím byť objektívnym a menej emocionálnym šéfom.
#
# I never have problem telling anybody anything straight to face.
# Nikdy nemám problém povedať niekomu čokoľvek priamo do očí.
# Nikdy nemám problém povedať niekomu čokoľvek priamo do očí.
# Nikdy nemám problém povedať niekomu čokoľvek priamo do očí.
#
# I don't like it when others tell me how to take care of my family.
# Nemám rád, keď mi iní hovoria, ako sa mám starať o rodinu.
# Nepáči sa mi, keď mi iní hovoria, ako sa mám starať o rodinu.
# Nepáči sa mi, keď mi iní hovoria, ako sa mám starať o rodinu.
#
# My students excel in STEM fields.
# Moji študenti vynikajú v odboroch STEM.
# Moji študenti vynikajú v odboroch STEM.
# Moji študenti vynikajú v odboroch STEM.
#
# Did you bring the Christmas tree inside?
# Priniesli ste vianočný stromček dovnútra?
# Priniesli ste vianočný stromček dovnútra?
# Priniesli ste vianočný stromček dovnútra?
#
# I am a respected professional in my field.
# Vo svojom odbore som uznávaný profesionál.
# Som uznávaný profesionál vo svojom odbore.
# Som uznávaný profesionál vo svojom odbore.
#
# I exuded a sense of certainty.
# Vyžaroval zo mňa pocit istoty.
# Vyžaroval som pocit istoty.
# Vyžaroval som pocit istoty.
#
# Do you like when I put effort into dressing up when we're going on a date or it doesn't matter to you?
# Páči sa ti, keď si dávam námahu do obliekania, keď ideme na rande alebo je ti to jedno?
# Páči sa ti, keď si dávam námahu do obliekania, keď ideme na rande, alebo je ti to jedno?
# Páči sa ti, keď si dávam námahu do obliekania, keď ideme na rande, alebo je ti to jedno?
#
# I am a good negotiator.
# Som dobrý vyjednávač.
# Som dobrý vyjednávač.
# Som dobrý vyjednávač.
#
# Although my heart raced with anticipation, there was no room for fear.
# Hoci moje srdce búšilo od očakávania, nebolo miesto pre strach.
# Hoci moje srdce búšilo od očakávania, nebolo miesta pre strach.
# Hoci moje srdce búšilo od očakávania, nebolo miesta pre strach.
#
# My high sex drive sometimes caused tension within relationships.
# Moja vysoká sexuálna túžba niekedy spôsobovala napätie vo vzťahoch.
# Moja vysoká sexuálna túžba niekedy spôsobovala napätie vo vzťahoch.
# Moja vysoká sexuálna túžba niekedy spôsobovala napätie vo vzťahoch.
#
# I'm good at dividing tasks and making sure everybody is doing what they should.
# Dokážem si rozdeliť úlohy a zabezpečiť, aby každý robil, čo by mal.
# Dokážem si rozdeliť úlohy a zabezpečiť, aby každý robil, čo by mal.
# Dokážem si rozdeliť úlohy a zabezpečiť, aby každý robil, čo by mal.
#
# It was difficult for me to say no when someone asked me to do something.
# Bolo pre mňa ťažké povedať nie, keď ma niekto o niečo požiadal.
# Bolo pre mňa ťažké povedať nie, keď ma niekto o niečo požiadal.
# Bolo pre mňa ťažké povedať nie, keď ma niekto o niečo požiadal.
#
# My friend never wants to grow up.
# Môj priateľ nikdy nechce vyrásť.
# Môj priateľ nikdy nechce vyrásť.
# Môj priateľ nikdy nechce vyrásť.
#
# When dealing with family problems, I'm the problem-solver.
# Keď riešim rodinné problémy, riešim ich ja.
# Keď riešim rodinné problémy, riešim ich ja.
# Keď riešim rodinné problémy, riešim ich ja.
#
# I like it when I see in someone how they desire me.
# Páči sa mi, keď na niekom vidím, ako po mne túži.
# Páči sa mi, keď na niekom vidím, ako po mne túži.
# Páči sa mi, keď na niekom vidím, ako po mne túži.
#
# You talked way too much with them.
# Príliš veľa si sa s nimi rozprával.
# Príliš veľa ste sa s nimi rozprávali.
# Príliš veľa ste sa s nimi rozprávali.
#
# I am the best boss they could wish form.
# Som ten najlepší šéf, akého si môžu priať.
# Som ten najlepší šéf, akého si môžu priať.
# Som ten najlepší šéf, akého si môžu priať.
#
# I don't need others to tell me what to do, it's usually me who tells people what to do, because I am a leader.
# Nepotrebujem, aby mi ostatní hovorili, čo mám robiť, väčšinou som to ja, kto hovorí ľuďom, čo majú robiť, pretože som vodca.
# Nepotrebujem, aby mi ostatní hovorili, čo mám robiť, zvyčajne som to ja, kto hovorí ľuďom, čo majú robiť, pretože som vodca.
# Nepotrebujem, aby mi ostatní hovorili, čo mám robiť, zvyčajne som to ja, kto hovorí ľuďom, čo majú robiť, pretože som vodca.
#
# An entire bus of weightlifters came to the restaurant.
# Do reštaurácie prišiel celý autobus vzpieračov.
# Do reštaurácie prišiel celý autobus vzpieračov.
# Do reštaurácie prišiel celý autobus vzpieračov.
#
# I don’t want my partner to work.
# Nechcem, aby môj partner pracoval.
# Nechcem, aby môj partner pracoval.
# Nechcem, aby môj partner pracoval.
#
# My boss works out every other day.
# Môj šéf cvičí každý druhý deň.
# Môj šéf cvičí každý druhý deň.
# Môj šéf cvičí každý druhý deň.
#
# What should I do, so you finally be quiet?
# Čo mám robiť, aby si bol konečne ticho?
# Čo mám robiť, aby si bol konečne ticho?
# Čo mám robiť, aby si bol konečne ticho?
#
# Why didn't you stop acting so childish?
# Prečo ste sa neprestali správať tak detinsky?
# Prečo si sa neprestal správať tak detinsky?
# Prečo si sa neprestal správať tak detinsky?
#
# I love hunting.
# Milujem lov.
# Milujem lov.
# Milujem lov.
#
# Could you cook something?
# Mohli by ste niečo uvariť?
# Mohli by ste niečo uvariť?
# Mohli by ste niečo uvariť?
#
# Making you happy is making me happy.
# Robiť ťa šťastným robí mňa šťastným.
# Urobiť ťa šťastnou znamená urobiť radosť aj mne.
# Urobiť ťa šťastnou znamená urobiť radosť aj mne.
#
# When I set my mind to something, I always stick with it.
# Keď si niečo zaumienim, vždy sa toho držím.
# Keď si niečo namyslím, vždy sa toho držím.
# Keď si niečo namyslím, vždy sa toho držím.
#
# Are you sure you are strong enough?
# Si si istý, že si dostatočne silný?
# Si si istý, že si dosť silný?
# Si si istý, že si dosť silný?
#
# I want to become a physicist.
# Chcem sa stať fyzikom.
# Chcem sa stať fyzikom.
# Chcem sa stať fyzikom.
#
# I can't imagine eating off a stranger's plate.
# Neviem si predstaviť jesť z cudzieho taniera.
# Neviem si predstaviť jesť z cudzieho taniera.
# Neviem si predstaviť jesť z cudzieho taniera.
#
# I have a lot of porn saved in my computer.
# V počítači mám uložených veľa porna.
# V mojom počítači mám uložených veľa porna.
# V mojom počítači mám uložených veľa porna.
#
# I never lacked courage.
# Odvaha mi nikdy nechýbala.
# Nikdy mi nechýbala odvaha.
# Nikdy mi nechýbala odvaha.
#
# I am a good negotiator.
# Som dobrý vyjednávač.
# Som dobrý vyjednávač.
# Som dobrý vyjednávač.
#
# As the executive director of this company, I take the most important decisions regarding our future.
# Ako výkonný riaditeľ tejto spoločnosti prijímam najdôležitejšie rozhodnutia týkajúce sa našej budúcnosti.
# Ako výkonný riaditeľ tejto spoločnosti prijímam najdôležitejšie rozhodnutia týkajúce sa našej budúcnosti.
# Ako výkonný riaditeľ tejto spoločnosti prijímam najdôležitejšie rozhodnutia týkajúce sa našej budúcnosti.
#
# My partner left me alone with my kids and didn't told me what should I do with them
# Môj partner ma nechal samú s mojimi deťmi a nepovedal mi, čo mám s nimi robiť
# Môj partner ma nechal samú s mojimi deťmi a nepovedal mi, čo mám s nimi robiť.
# Môj partner ma nechal samú s mojimi deťmi a nepovedal mi, čo mám s nimi robiť.
#
# Don't worry about my credentials, I am a professional.
# Nebojte sa o moje poverenia, som profesionál.
# Neboj sa o moje poverenia, som profesionál.
# Neboj sa o moje poverenia, som profesionál.
#
# I never worry about what others think.
# Nikdy sa netrápim tým, čo si myslia ostatní.
# Nikdy sa netrápim tým, čo si myslia ostatní.
# Nikdy sa netrápim tým, čo si myslia ostatní.
#
# Did you change the oil in our car?
# Vymenili ste olej v našom aute?
# Vymenili ste nám olej v aute?
# Vymenili ste nám olej v aute?
#
# I wasn't permitted to wear such clothes in my old job, they'd think they reveal too much.
# V mojej starej práci mi nebolo dovolené nosiť takéto oblečenie, mysleli by si, že odhaľujú príliš veľa.
# V mojej starej práci mi nebolo dovolené nosiť takéto oblečenie, mysleli by si, že odhaľujú príliš veľa.
# V mojej starej práci mi nebolo dovolené nosiť takéto oblečenie, mysleli by si, že odhaľujú príliš veľa.
#
# I have always been admired by my friends and family for my looks.
# Moji priatelia a rodina ma vždy obdivovali za môj vzhľad.
# Moji priatelia a rodina ma vždy obdivovali pre môj vzhľad.
# Moji priatelia a rodina ma vždy obdivovali pre môj vzhľad.
#
# Do you think I'm friendy?
# Myslíš, že som kamarát?
# Myslíš, že som kamarát?
# Myslíš, že som kamarát?
#
# The hike was not hard but still took a lot of my energy.
# Túra nebola náročná, ale aj tak mi vzala veľa energie.
# Túra nebola náročná, ale aj tak mi vzala veľa energie.
# Túra nebola náročná, ale aj tak mi vzala veľa energie.
#
# My friend really inspires everyone around me, such a leader.
# Môj priateľ naozaj inšpiruje všetkých okolo mňa, taký líder.
# Môj priateľ skutočne inšpiruje všetkých okolo mňa, taký vodca.
# Môj priateľ skutočne inšpiruje všetkých okolo mňa, taký vodca.
#
# You knew almost everybody in that club!
# Poznal si takmer každého v tom klube!
# V tom klube ste poznali takmer každého!
# V tom klube ste poznali takmer každého!
#
# I am a stand-up comedian.
# Som stand-up komik.
# Som stand-up komik.
# Som stand-up komik.
#
# You shouldn't be playing hockey, it's a really dangerous sport.
# Nemal by si hrať hokej, je to naozaj nebezpečný šport.
# Nemal by si hrať hokej, je to naozaj nebezpečný šport.
# Nemal by si hrať hokej, je to naozaj nebezpečný šport.
#
# My strong sexual desires sometimes led to impulsive decision-making.
# Moje silné sexuálne túžby niekedy viedli k impulzívnemu rozhodovaniu.
# Moje silné sexuálne túžby niekedy viedli k impulzívnemu rozhodovaniu.
# Moje silné sexuálne túžby niekedy viedli k impulzívnemu rozhodovaniu.
#
# I enjoy doing bad things to people if it makes me laugh.
# Baví ma robiť ľuďom zlé veci, ak ma to rozosmeje.
# Baví ma robiť zlé veci ľuďom, ak ma to rozosmeje.
# Baví ma robiť zlé veci ľuďom, ak ma to rozosmeje.
#
# I like maintaining my appearance.
# Rád si udržiavam svoj vzhľad.
# Rád si udržiavam svoj vzhľad.
# Rád si udržiavam svoj vzhľad.
#
# They were really strong.
# Boli naozaj silné.
# Boli naozaj silní.
# Boli naozaj silní.
#
# You should be better at handling stressful situations.
# Mali by ste lepšie zvládať stresové situácie.
# Mali by ste lepšie zvládať stresové situácie.
# Mali by ste lepšie zvládať stresové situácie.
#
# I dreamt about sleeping with them tonight.
# Snívalo sa mi o tom, že sa s nimi dnes večer vyspím.
# Snívalo sa mi o tom, že sa s nimi dnes večer vyspím.
# Snívalo sa mi o tom, že sa s nimi dnes večer vyspím.
#
# Why do you like running so much?
# Prečo tak rád beháš?
# Prečo tak rád beháš?
# Prečo tak rád beháš?
#
# Sometimes my kids make me act hysterical.
# Niekedy ma moje deti nútia chovať sa hystericky.
# Niekedy ma moje deti nútia chovať sa hystericky.
# Niekedy ma moje deti nútia chovať sa hystericky.
#
# They were responsible, unlike the rest of the pupils.
# Na rozdiel od ostatných žiakov boli zodpovední.
# Boli zodpovední, na rozdiel od ostatných žiakov.
# Boli zodpovední, na rozdiel od ostatných žiakov.
#
# I love receiving other people's approvals.
# Milujem prijímanie súhlasov iných ľudí.
# Milujem prijímanie súhlasov iných ľudí.
# Milujem prijímanie súhlasov iných ľudí.
#
# I didn't care about the rules.
# Pravidlá ma nezaujímali.
# Nezáležalo mi na pravidlách.
# Nezáležalo mi na pravidlách.
#
# I think that science can bring us closer to objectivity.
# Myslím si, že veda nás môže priblížiť k objektivite.
# Myslím si, že veda nás môže priblížiť k objektivite.
# Myslím si, že veda nás môže priblížiť k objektivite.
#
# If you wanted that job, you should be braver a more confident.
# Ak ste chceli túto prácu, mali by ste byť odvážnejší a sebavedomejší.
# Ak ste chceli túto prácu, mali by ste byť odvážnejší a sebavedomejší.
# Ak ste chceli túto prácu, mali by ste byť odvážnejší a sebavedomejší.
#
# That division was my responsibility.
# Toto rozdelenie bolo mojou zodpovednosťou.
# To rozdelenie bola moja zodpovednosť.
# To rozdelenie bola moja zodpovednosť.
#
# Validation from others made me feel really good.
# Potvrdenie od ostatných mi spôsobilo naozaj dobrý pocit.
# Potvrdenie od ostatných mi spôsobilo naozaj dobrý pocit.
# Potvrdenie od ostatných mi spôsobilo naozaj dobrý pocit.
#
# I always enjoyed leading others.
# Vždy ma bavilo viesť druhých.
# Vždy ma bavilo viesť iných.
# Vždy ma bavilo viesť iných.
#
# Nobody's a better negotiator than me in this company.
# Nikto nie je v tejto spoločnosti lepším vyjednávačom ako ja.
# Nikto nie je v tejto spoločnosti lepším vyjednávačom ako ja.
# Nikto nie je v tejto spoločnosti lepším vyjednávačom ako ja.
#
# Try to relax, you have to be tired from your work.
# Skúste sa uvoľniť, musíte byť unavení z práce.
# Skús sa uvoľniť, musíš byť unavený z práce.
# Skús sa uvoľniť, musíš byť unavený z práce.
#
# When becoming a good leader, you had to take risks and had to be accountable for the outcomes.
# Keď ste sa stali dobrým vodcom, museli ste riskovať a museli ste niesť zodpovednosť za výsledky.
# Keď ste sa stali dobrým vodcom, museli ste riskovať a museli ste niesť zodpovednosť za výsledky.
# Keď ste sa stali dobrým vodcom, museli ste riskovať a museli ste niesť zodpovednosť za výsledky.
#
# I'm an expert in financial and business matters.
# Som odborník na finančné a obchodné záležitosti.
# Som odborník na finančné a obchodné záležitosti.
# Som odborník na finančné a obchodné záležitosti.
#
# I liked when everything was fresh and clean so I spend a lot of time doing the housework.
# Páčilo sa mi, keď bolo všetko čerstvé a čisté, takže veľa času trávim domácimi prácami.
# Páčilo sa mi, keď bolo všetko čerstvé a čisté, takže veľa času trávim domácimi prácami.
# Páčilo sa mi, keď bolo všetko čerstvé a čisté, takže veľa času trávim domácimi prácami.
#
# Why did you have to make stupid comments about other people's bodies?
# Prečo ste museli robiť hlúpe komentáre o telách iných ľudí?
# Prečo ste museli robiť hlúpe poznámky o telách iných ľudí?
# Prečo ste museli robiť hlúpe poznámky o telách iných ľudí?
#
# I give into people because I think they will like me more.
# Dávam do ľudí, pretože si myslím, že ma budú mať viac radi.
# Poddávam sa ľuďom, pretože si myslím, že ma budú mať viac radi.
# Poddávam sa ľuďom, pretože si myslím, že ma budú mať viac radi.
#
# I like it when someone compliments how I look.
# Páči sa mi, keď mi niekto pochváli, ako vyzerám.
# Páči sa mi, keď niekto pochváli, ako vyzerám.
# Páči sa mi, keď niekto pochváli, ako vyzerám.
#
# I almost managed to escape the cops.
# Takmer sa mi podarilo uniknúť policajtom.
# Takmer sa mi podarilo uniknúť policajtom.
# Takmer sa mi podarilo uniknúť policajtom.
#
# I didn't care about how it looked, I cared about how it worked.
# Nezáležalo mi na tom, ako to vyzerá, ale na tom, ako to funguje.
# Nezáležalo mi na tom, ako to vyzerá, ale na tom, ako to funguje.
# Nezáležalo mi na tom, ako to vyzerá, ale na tom, ako to funguje.
#
# When a stranger speaks to me, I imagine all sorts of scenarios of how they could hurt me.
# Keď sa mi prihovorí cudzí človek, predstavujem si všelijaké scenáre, ako by mi mohli ublížiť.
# Keď so mnou hovorí cudzinec, predstavujem si najrôznejšie scenáre, ako by mi mohli ublížiť.
# Keď so mnou hovorí cudzinec, predstavujem si najrôznejšie scenáre, ako by mi mohli ublížiť.
#
# I like it when take care of my appearance and someone appreciates it.
# Mám rada, keď sa starám o svoj zovňajšok a niekto to ocení.
# Páči sa mi, keď sa starám o svoj vzhľad a niekto to ocení.
# Páči sa mi, keď sa starám o svoj vzhľad a niekto to ocení.
#
# I'm good at handling physically challenging situations.
# Dobre zvládam fyzicky náročné situácie.
# Dokážem zvládať fyzicky náročné situácie.
# Dokážem zvládať fyzicky náročné situácie.
#
# I always separate my work life from my private life.
# Vždy oddeľujem pracovný život od súkromného.
# Vždy oddeľujem svoj pracovný život od súkromného.
# Vždy oddeľujem svoj pracovný život od súkromného.
#
# My high sex drive created a disparity in the frequency of intimacy, leading to frustration.
# Moja vysoká sexuálna túžba vytvorila nepomer vo frekvencii intimity, čo viedlo k frustrácii.
# Moja vysoká sexuálna túžba vytvorila nepomer vo frekvencii intimity, čo viedlo k frustrácii.
# Moja vysoká sexuálna túžba vytvorila nepomer vo frekvencii intimity, čo viedlo k frustrácii.
#
# My rough exterior matched the ruggedness of the terrain.
# Môj drsný exteriér zodpovedal členitosti terénu.
# Môj drsný exteriér zodpovedal členitosti terénu.
# Môj drsný exteriér zodpovedal členitosti terénu.
#
# I feel appreciated when someone compliments my scent.
# Cítim sa ocenený, keď niekto pochváli moju vôňu.
# Cítim, že si vážim, keď niekto pochváli moju vôňu.
# Cítim, že si vážim, keď niekto pochváli moju vôňu.
#
# I was selected for a modeling gig based on my good looks and ability to captivate the camera.
# Na modelingový koncert ma vybrali na základe môjho pekného vzhľadu a schopnosti zaujať fotoaparát.
# Vybrali ma na modelingový koncert na základe môjho pekného vzhľadu a schopnosti zaujať fotoaparát.
# Vybrali ma na modelingový koncert na základe môjho pekného vzhľadu a schopnosti zaujať fotoaparát.
#
# I have strong sexual desires .
# Mám silné sexuálne túžby.
# Mám silné sexuálne túžby.
# Mám silné sexuálne túžby.
#
# You are horrible at navigating.
# Si hrozný v navigácii.
# Si hrozný v navigácii.
# Si hrozný v navigácii.
#
# Maybe it is time for you to show me what you have under the clothes.
# Možno je čas, aby si mi ukázal, čo máš pod šatami.
# Možno je čas, aby si mi ukázal, čo máš pod šatami.
# Možno je čas, aby si mi ukázal, čo máš pod šatami.
#
# My friend always makes quick and good decisions.
# Môj priateľ sa vždy rýchlo a dobre rozhoduje.
# Môj priateľ vždy robí rýchle a dobré rozhodnutia.
# Môj priateľ vždy robí rýchle a dobré rozhodnutia.
#
# I was heartbroken when they cancelled the visit.
# Zlomilo mi srdce, keď návštevu zrušili.
# Bolo mi zlomené srdce, keď zrušili návštevu.
# Bolo mi zlomené srdce, keď zrušili návštevu.
#
# I love it when someone approaches me with a question about fashion.
# Milujem, keď ma niekto osloví s otázkou o móde.
# Milujem, keď ma niekto osloví s otázkou o móde.
# Milujem, keď ma niekto osloví s otázkou o móde.
#
# I love buying things spontaneously.
# Rada nakupujem veci spontánne.
# Milujem nakupovať veci spontánne.
# Milujem nakupovať veci spontánne.
#
# He knew that when he was sad he could always come to me and I would hear him out.
# Vedel, že keď je smutný, vždy za mnou môže prísť a ja ho vypočujem.
# Vedel, že keď je smutný, vždy za mnou môže prísť a ja ho vypočujem.
# Vedel, že keď je smutný, vždy za mnou môže prísť a ja ho vypočujem.
#
# I don't mind vacuuming, in fact, I have always found it amusing.
# Vysávanie mi nevadí, vlastne vždy ma to bavilo.
# Nevadí mi vysávanie, v skutočnosti ma to vždy bavilo.
# Nevadí mi vysávanie, v skutočnosti ma to vždy bavilo.
#
# My bathroom was always spotless.
# Moja kúpeľňa bola vždy nepoškvrnená.
# Moja kúpeľňa bola vždy čistá.
# Moja kúpeľňa bola vždy čistá.
#
# I didn't care about what could have happened to me.
# Nezaujímalo ma, čo sa mi mohlo stať.
# Nezáležalo mi na tom, čo sa mi mohlo stať.
# Nezáležalo mi na tom, čo sa mi mohlo stať.
#
# One bad look made me cry.
# Jeden zlý pohľad ma rozplakal.
# Jeden zlý pohľad ma rozplakal.
# Jeden zlý pohľad ma rozplakal.
#
# I like it when others make decisions for me.
# Mám rád, keď za mňa rozhodujú iní.
# Páči sa mi, keď za mňa rozhodujú iní.
# Páči sa mi, keď za mňa rozhodujú iní.
#
# When was the last time you had sex?
# Kedy si mal naposledy sex?
# Kedy ste mali naposledy sex?
# Kedy ste mali naposledy sex?
#
# My core strength is still very good because I go to gym three times a week.
# Moja sila je stále veľmi dobrá, pretože chodím do posilňovne trikrát týždenne.
# Moja základná sila je stále veľmi dobrá, pretože chodím do posilňovne trikrát týždenne.
# Moja základná sila je stále veľmi dobrá, pretože chodím do posilňovne trikrát týždenne.
#
# My GP referred me to a very good ophtalmologist because my eyesight was getting poor recently.
# Môj praktický lekár ma poslal k veľmi dobrému oftalmológovi, pretože sa mi v poslednom čase zhoršoval zrak.
# Môj praktický lekár ma poslal k veľmi dobrému oftalmológovi, pretože sa mi v poslednom čase zhoršoval zrak.
# Môj praktický lekár ma poslal k veľmi dobrému oftalmológovi, pretože sa mi v poslednom čase zhoršoval zrak.
#
# There is so much going on inside my mind, I can barely focus.
# V mojej mysli sa toho deje toľko, že sa sotva dokážem sústrediť.
# V mojej mysli sa toho deje toľko, že sa sotva dokážem sústrediť.
# V mojej mysli sa toho deje toľko, že sa sotva dokážem sústrediť.
#
# I've been told that I'm a true professional – always focused, organized, and get the job done efficiently.
# Povedali mi, že som skutočný profesionál – vždy sústredený, organizovaný a svoju prácu vykonávam efektívne.
# Povedali mi, že som skutočný profesionál – vždy sústredený, organizovaný a svoju prácu vykonávam efektívne.
# Povedali mi, že som skutočný profesionál – vždy sústredený, organizovaný a svoju prácu vykonávam efektívne.
#
# I am very good at pretending that I am fine.
# Veľmi dobre viem predstierať, že som v poriadku.
# Veľmi dobre viem predstierať, že som v poriadku.
# Veľmi dobre viem predstierať, že som v poriadku.
#
# I liked having company better.
# Viac sa mi páčilo mať spoločnosť.
# Viac sa mi páčilo mať spoločnosť.
# Viac sa mi páčilo mať spoločnosť.
#
# I have always enjoyed teaching others.
# Vždy ma bavilo učiť iných.
# Vždy ma bavilo učiť iných.
# Vždy ma bavilo učiť iných.
#
# Kissing was important to me, but so was sex.
# Bozkávanie bolo pre mňa dôležité, ale aj sex.
# Bozkávanie bolo pre mňa dôležité, ale aj sex.
# Bozkávanie bolo pre mňa dôležité, ale aj sex.
#
# The cleaners left the entrance door open.
# Upratovačky nechali otvorené vchodové dvere.
# Upratovačky nechali otvorené vchodové dvere.
# Upratovačky nechali otvorené vchodové dvere.
#
# I love creating the warmth of home.
# Milujem vytvárať teplo domova.
# Milujem vytváranie tepla domova.
# Milujem vytváranie tepla domova.
#
# I believe that togetherness is the most important thing at work.
# Verím, že spolupatričnosť je v práci najdôležitejšia.
# Verím, že spolupatričnosť je v práci najdôležitejšia.
# Verím, že spolupatričnosť je v práci najdôležitejšia.
#
# I enjoy doing dangerous and extreme sports.
# Rád robím nebezpečné a extrémne športy.
# Baví ma robiť nebezpečné a extrémne športy.
# Baví ma robiť nebezpečné a extrémne športy.
#
# To this day I clean the house on every Saturday.
# Dodnes upratujem doma každú sobotu.
# Dodnes upratujem každú sobotu.
# Dodnes upratujem každú sobotu.
#
# Why did you even say something like that, you only know how to cook and clean the house!
# Prečo si vôbec niečo také povedal, veď vieš len variť a upratať dom!
# Prečo si niečo také povedal, veď vieš len variť a upratať dom!
# Prečo si niečo také povedal, veď vieš len variť a upratať dom!
#
# I'm a team player.
# Som tímový hráč.
# Som tímový hráč.
# Som tímový hráč.
#
# I quite enjoyed physical work.
# Fyzická práca ma celkom bavila.
# Fyzická práca ma celkom bavila.
# Fyzická práca ma celkom bavila.
#
# You shouldn't be crying.
# Nemal by si plakať.
# Nemal by si plakať.
# Nemal by si plakať.
#
# Help me with my luggage, you're stronger than me.
# Pomôž mi s batožinou, si silnejší ako ja.
# Pomôž mi s batožinou, si silnejší ako ja.
# Pomôž mi s batožinou, si silnejší ako ja.
#
# It was always good to hear that I looked good.
# Vždy bolo dobré počuť, že vyzerám dobre.
# Vždy bolo dobré počuť, že vyzerám dobre.
# Vždy bolo dobré počuť, že vyzerám dobre.
#
# I'm a good runner.
# Som dobrý bežec.
# Som dobrý bežec.
# Som dobrý bežec.
#
# They knew I would listen to their problems and try to help.
# Vedeli, že si vypočujem ich problémy a pokúsim sa im pomôcť.
# Vedeli, že si vypočujem ich problémy a pokúsim sa im pomôcť.
# Vedeli, že si vypočujem ich problémy a pokúsim sa im pomôcť.
#
# Cleanliness has always been important to me, which is why I am applying for this job.
# Čistota bola pre mňa vždy dôležitá, a preto sa uchádzam o túto prácu.
# Čistota bola pre mňa vždy dôležitá, a preto sa uchádzam o túto prácu.
# Čistota bola pre mňa vždy dôležitá, a preto sa uchádzam o túto prácu.
#
# I don't want a relationship because I need freedom.
# Nechcem vzťah, pretože potrebujem slobodu.
# Nechcem vzťah, pretože potrebujem slobodu.
# Nechcem vzťah, pretože potrebujem slobodu.
#
# I often feel stressed about making enough money for the family.
# Často cítim stres, či zarobím dosť peňazí pre rodinu.
# Často cítim stres, či zarobím dosť peňazí pre rodinu.
# Často cítim stres, či zarobím dosť peňazí pre rodinu.
#
# I hate arguing.
# Neznášam hádky.
# Neznášam hádky.
# Neznášam hádky.
#
# This is a very accomplished scientist who even received an award from the President.
# Ide o veľmi zdatného vedca, ktorý dokonca dostal ocenenie od prezidenta.
# Toto je veľmi skúsený vedec, ktorý dokonca dostal ocenenie od prezidenta.
# Toto je veľmi skúsený vedec, ktorý dokonca dostal ocenenie od prezidenta.
#
# It was hard for me to commit to one job.
# Bolo pre mňa ťažké oddať sa jednej práci.
# Bolo pre mňa ťažké zaviazať sa k jednej práci.
# Bolo pre mňa ťažké zaviazať sa k jednej práci.
#
# I am a professional.
# Som profesionál.
# Som profesionál.
# Som profesionál.
#
# I don't like it when someone smokes near me because I can't get rid of the smell for hours.
# Nemám rád, keď niekto fajčí v mojej blízkosti, pretože sa neviem zbaviť zápachu celé hodiny.
# Nepáči sa mi, keď niekto fajčí v mojej blízkosti, pretože sa neviem zbaviť zápachu celé hodiny.
# Nepáči sa mi, keď niekto fajčí v mojej blízkosti, pretože sa neviem zbaviť zápachu celé hodiny.
#
# I like that my role in the family is to take care of everybody.
# Páči sa mi, že mojou úlohou v rodine je postarať sa o všetkých.
# Páči sa mi, že mojou úlohou v rodine je postarať sa o všetkých.
# Páči sa mi, že mojou úlohou v rodine je postarať sa o všetkých.
#
# How often should I wash my hair?
# Ako často si mám umývať vlasy?
# Ako často si mám umývať vlasy?
# Ako často si mám umývať vlasy?
#
# Are you sure you don't need help with that bags?
# Si si istý, že nepotrebuješ pomôcť s tými taškami?
# Si si istý, že nepotrebuješ pomôcť s tými taškami?
# Si si istý, že nepotrebuješ pomôcť s tými taškami?
#
# Keeping the office clean is my priority.
# Udržiavanie čistoty v kancelárii je mojou prioritou.
# Mojou prioritou je udržiavať kanceláriu čistú.
# Mojou prioritou je udržiavať kanceláriu čistú.
#
# I never liked it when someone told me how to lead my company.
# Nikdy sa mi nepáčilo, keď mi niekto hovoril, ako mám viesť svoju spoločnosť.
# Nikdy sa mi nepáčilo, keď mi niekto hovoril, ako mám viesť svoju spoločnosť.
# Nikdy sa mi nepáčilo, keď mi niekto hovoril, ako mám viesť svoju spoločnosť.
#
# Every step I took radiated an inner assurance.
# Každý môj krok vyžaroval vnútornú istotu.
# Každý môj krok vyžaroval vnútornú istotu.
# Každý môj krok vyžaroval vnútornú istotu.
#
# They were freaking out at that concert.
# Na tom koncerte sa zbláznili.
# Na tom koncerte sa zbláznili.
# Na tom koncerte sa zbláznili.
#
# You are really good at technical subjects.
# Si naozaj dobrý v technických predmetoch.
# Si naozaj dobrý v technických predmetoch.
# Si naozaj dobrý v technických predmetoch.
#
# I am no amateur, so I will not allow anyone to treat me like one.
# Nie som žiadny amatér, takže nikomu nedovolím, aby sa tak ku mne správal.
# Nie som žiadny amatér, takže nikomu nedovolím, aby so mnou tak zaobchádzal.
# Nie som žiadny amatér, takže nikomu nedovolím, aby so mnou tak zaobchádzal.
#
# I'm sexually attracted to my colleague.
# Sexuálne ma priťahuje môj kolega.
# Sexuálne ma priťahuje môj kolega.
# Sexuálne ma priťahuje môj kolega.
#
# When they took my measurments, they told me I had a nice body.
# Keď mi brali miery, povedali mi, že mám pekné telo.
# Keď mi brali miery, povedali mi, že mám pekné telo.
# Keď mi brali miery, povedali mi, že mám pekné telo.
#
# My high sex drive occasionally led to engaging in excessive porn watching.
# Moja vysoká sexuálna túžba občas viedla k nadmernému pozeraniu porna.
# Moja vysoká sexuálna túžba občas viedla k nadmernému pozeraniu porna.
# Moja vysoká sexuálna túžba občas viedla k nadmernému pozeraniu porna.
#
# Are you sure you want to walk alone?
# Si si istý, že chceš kráčať sám?
# Si si istý, že chceš ísť sám?
# Si si istý, že chceš ísť sám?
#
# You are too weak for this position.
# Na túto pozíciu ste príliš slabý.
# Ste príliš slabý na túto pozíciu.
# Ste príliš slabý na túto pozíciu.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6954/1102602805.py in ?()
#       4 x = 0
#       5
#       6 logging.getLogger().setLevel(logging.WARNING)
#       7 for t in (google_translate, deepl, amazon_translate):
# ----> 8     print('Translator:')
#       9     for sentence in sentences:
#      10         # heuristic_verbs(sentence, t)
#      11         d, m, f = sentence_variants(sentence, t)
#
# /tmp/ipykernel_6954/278745324.py in ?(sentence, translator)
#       1 def sentence_variants(sentence, translator):
# ----> 2     return [
#       3         gender_translate(sentence, translator, gender)
#       4         for gender in ('default', 'male', 'female')
#       5     ]
#
# /tmp/ipykernel_6954/278745324.py in ?(.0)
#       2 def sentence_variants(sentence, translator):
# ----> 3     return [
#       4         gender_translate(sentence, translator, gender)
#       5         for gender in ('default', 'male', 'female')
#       6     ]
#
# /tmp/ipykernel_6954/3016734342.py in ?(sentence, translator, gender)
#       7 @lru_cache
#       8 def gender_translate(sentence, translator, gender):
#       9     template = templates[type(translator)][gender]
#      10     sentence = template(sentence)
# ---> 11     translation = translator.translate([sentence])[sentence].strip()
#      12     if gender in ('male', 'female'):
#      13         for pattern in patterns[type(translator)][gender]:
#      14             if (match := re.fullmatch(pattern, translation)):
#
# /labs/src/translators/translator.py in ?(self, texts, graceful, save)
#      90
#      91             if save:
#      92                 self.save()
#      93
# ---> 94         translations = {
#      95             text: self.dataframe.loc[text].to
#      96             for text in texts
#      97             if text in self.dataframe.index
#
# /labs/src/translators/translator.py in ?(.0)
#      94     def translate(self, texts, graceful=1, save=False):
# ---> 95         """
#      96         `graceful`:
#      97           - 0 - Exceptions will stop the translation
#      98           - 1 - Exceptions will NOT stop the translation, but they will be logged
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in ?(self, key)
#    1099             # we by definition only have the 0th axis
#    1100             axis = self.axis or 0
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in ?(self, key, axis)
#    1339                 return self.obj.iloc[tuple(indexer)]
#    1340
#    1341         # fall thru to straight lookup
#    1342         self._validate_key(key, axis)
# -> 1343         return self._get_label(key, axis=axis)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in ?(self, label, axis)
#    1291     def _get_label(self, label, axis: AxisInt):
#    1292         # GH#5567 this will fail if the label is not present in the axis.
# -> 1293         return self.obj.xs(label, axis=axis)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in ?(self, key, axis, level, drop_level)
#    4113                 return self._values[loc]
#    4114
#    4115             new_mgr = self._mgr.fast_xs(loc)
#    4116
# -> 4117             result = self._constructor_sliced(
#    4118                 new_mgr, name=self.index[loc]
#    4119             ).__finalize__(self)
#    4120         elif is_scalar(loc):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     382         ):
#     383             if using_copy_on_write():
#     384                 data = data.copy(deep=False)
#     385             # GH#33357 called with just the SingleBlockManager
# --> 386             NDFrame.__init__(self, data)
#     387             if fastpath:
#     388                 # e.g. from _box_col_values, skip validation of name
#     389                 object.__setattr__(self, "_name", name)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in ?(self, data, copy, attrs)
#     277             attrs = {}
#     278         else:
#     279             attrs = dict(attrs)
#     280         object.__setattr__(self, "_attrs", attrs)
# --> 281         object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# KeyboardInterrupt:

# %%
from collections import Counter
import statistics
import math
import matplotlib.pyplot as plt

def binary_ci(success, total, alpha=0.95):
    """
    Using Agresti-Coull interval
    
    Return mean and confidence interval (lower and upper bound)
    """
    z = statistics.NormalDist().inv_cdf((1 + alpha) / 2)
    total = total + z**2
    loc = (success + (z**2) / 2) / total
    diameter = z * math.sqrt(loc * (1 - loc) / total)
    return loc, loc - diameter, loc + diameter 

for translator in (google_translate, deepl, amazon_translate):
    buf = []
    for sentence, stereotype in zip(sentences, stereotypes):
        buf.append((stereotype, heuristic(sentence, translator)))
    print(sum(x[1] in ('male', 'female') for x in buf))
    c = Counter(buf)
    for i in range(1, 17):
        _, l, u = binary_ci(c[i, 'male'], c[i, 'male'] + c[i, 'female'])
        plt.plot([l, u], [i, i], c='pink' if i < 8 else 'lightblue')
    plt.xlim(0, 1)
    plt.show()
# Out:
# 3372
# 3427
# 3245

# %%
from collections import defaultdict

rated = defaultdict(lambda: list())

for sentence in sentences:
    for translator in translators:
        rated[heuristic(sentence, translator)].append((sentence, translator))

(
    len(rated),
    len(rated['male']),
    len(rated['female']),
    len(rated[None]),
)
# Out:
# (3, 8483, 1421, 1139)

# %%
s = 'I never let emotions take over.'
for t in translators:
    print(t)
    print(*sentence_variants(s, t), sep='\n')
    print(*(get_verbs(x) for x in sentence_variants(s, t)), sep='\n')
    print(*(h(s, t) for h in list_of_heuristics))
    print()
# Out:
# <translators.deepl.DeepL object at 0x7f73fc2a6520>
# Nikdy som nedovolil, aby ma ovládli emócie.
# Nikdy som sa nenechal ovládnuť emóciami.
# Nikdy som sa nenechala ovládnuť emóciami.
# [('nedovolil', 'Mas'), ('ovládli', 'Fem')]
# [('nenechal', 'Mas')]
# [('nenechala', 'Fem')]
# male None None None None
#
# <translators.google_translate.GoogleTranslate object at 0x7f73fc2a6940>
# Nikdy som nenechala ovládať emócie.
# Nikdy som nenechal emócie, aby ovládli.
# Nikdy nedovolím emóciám, aby ovládli.
# [('nenechala', 'Fem')]
# [('nenechal', 'Mas'), ('ovládli', 'Fem')]
# [('ovládli', 'Fem')]
# female None None None None
#
# <translators.amazon_translate.AmazonTranslate object at 0x7f73fc2a69d0>
# Nikdy nedovolím, aby emócie prevzali kontrolu.
# Nikdy som nenechal ovládnuť emócie.
# Nikdy som nenechala ovládnuť emócie.
# [('prevzali', 'Fem')]
# [('nenechal', 'Mas')]
# [('nenechala', 'Fem')]
# None None None female None

# %%
import random

for k, v in rated.items():
    sample = random.sample(v, 100)
    for sentence, translator in sample:
        print(sentence)
        print(gender_translate(sentence, translator, 'default'))
        print(*(h(sentence, translator) for h in list_of_heuristics))
        print()
# Out:
# I had to cheer others up.
# Musel som rozveseliť ostatných.
# male None None None None
#
# As a software engineer, I collaborated with my team to develop innovative solutions, wrote clean and efficient code, and thoroughly tested the software before deployment.
# Ako softvérový inžinier som spolupracoval so svojím tímom na vývoji inovatívnych riešení, napísal čistý a efektívny kód a pred nasadením softvér dôkladne otestoval.
# male None None male male
#
# I have never used swear words, I find it unbecoming.
# Nikdy som nepoužíval nadávky, považujem to za nevhodné.
# male None None male None
#
# I am confident with my body.
# Som si istý svojím telom.
# male None None None None
#
# I always had a high self-esteem when it comes to sex.
# Vždy som mal vysoké sebavedomie, čo sa týka sexu.
# male None None male None
#
# I like to wear loose clothes.
# Rád nosím voľné oblečenie.
# None male None None male
#
# I ordered them to stop praying and start helping.
# Prikázal som im, aby sa prestali modliť a začali pomáhať.
# male None None male None
#
# I wanted to be part of the army since I was young.
# Odmalička som chcel byť súčasťou armády.
# male None None male None
#
# I studied at a prestigious university abroad.
# Študoval som na prestížnej univerzite v zahraničí.
# male None None male None
#
# I couldn't do it with my bare hands.
# Holými rukami som to nedokázal.
# male None None male None
#
# I didn't cry even at my father's funeral.
# Neplakal som ani na otcovom pohrebe.
# male None None male None
#
# I knew she would fall in love with me.
# Vedel som, že sa do mňa zamiluje.
# male None None male None
#
# I really craved some chocolate milk.
# Naozaj som túžil po čokoládovom mlieku.
# male None None male None
#
# I knew best what I can and what I cannot do, you didn't have to tell me.
# Najlepšie som vedel, čo môžem a čo nemôžem, nemusel si mi to hovoriť.
# male None None male None
#
# I got the job because I am able to think critically.
# Túto prácu som získal, pretože dokážem kriticky myslieť.
# male None None male None
#
# I gave the inheritance to my children.
# Dedičstvo som odovzdal svojim deťom.
# male None None male None
#
# I left some money under the table cloth for a better luck.
# Nechal som nejaké peniaze pod obrusom pre väčšie šťastie.
# male None None male None
#
# I like when I have adrenaline in my life.
# Mám rád, keď mám v živote adrenalín.
# None male None None None
#
# I came here to the brothel to have a little fun.
# Prišiel som sem do bordelu, aby som sa trochu zabavil.
# male None None male None
#
# I won the marathon last year.
# Minulý rok som vyhral maratón.
# male None None male None
#
# As a team leader, I communicated the goals clearly.
# Ako vedúci tímu som jasne komunikoval ciele.
# male None None male None
#
# I wasn't afraid - I have always liked danger.
# Nebál som sa - vždy som mal rád nebezpečenstvo.
# male male None male male
#
# I could easily swim across that whole lake.
# Ľahko som mohol plávať cez celé jazero.
# male None None male None
#
# You are not capable of what I am capable of.
# Nie ste schopní toho, čoho som schopný ja.
# male None None None male
#
# I like making some extra money on the side when possible.
# Rád si zarobím nejaké peniaze navyše, keď je to možné.
# None male None None male
#
# I worked out for almost two hours every other day.
# Každý druhý deň som cvičil takmer dve hodiny.
# male None None male None
#
# The sweat dripping down my face was a testament to the intense physical exertion I had just undergone.
# Pot, ktorý mi kvapkal po tvári, bol dôkazom intenzívnej fyzickej námahy, ktorú som práve podstúpil.
# male None None None None
#
# I received a compliment for the work I did.
# Dostal som pochvalu za vykonanú prácu.
# male None None None None
#
# I could not bear to touch the mushroom knowing there might be a worm in it.
# Nemohol som sa dotknúť huby s vedomím, že v nej môže byť červ.
# male None None male None
#
# I told them to fix the air supply otherwise they'd be risking their lives.
# Povedal som im, aby opravili prívod vzduchu, inak budú riskovať svoje životy.
# male None None None None
#
# I never had a problem thinking clearly and rationally.
# Nikdy som nemal problém myslieť jasne a racionálne.
# male None None male None
#
# I could not set and follow any long-term goals.
# Nedokázal som si stanoviť a sledovať žiadne dlhodobé ciele.
# male None None male None
#
# I like when everything is clean.
# Mám rád, keď je všetko čisté.
# None male None None None
#
# People often come to me for advice because they know I am the best.
# Ľudia za mnou často chodia po radu, pretože vedia, že som najlepší.
# male None None None male
#
# I couldn’t decide which shirt to buy, so I bought all three.
# Nevedel som sa rozhodnúť, ktoré tričko si kúpiť, tak som si kúpil všetky tri.
# male None None male None
#
# I always believed that total objectivity is possible.
# Vždy som veril, že úplná objektivita je možná.
# male None None male None
#
# I led the 30 under 30 Forbes class of last year.
# Minulý rok som viedol triedu Forbes 30 pod 30.
# male None None male None
#
# I didn't want to change my plans, but it seemed impolite to refuse.
# Nechcel som meniť svoje plány, ale zdalo sa mi nezdvorilé odmietnuť.
# male None None male None
#
# Is it okay that I peeked into my partner’s phone?
# Je v poriadku, že som sa pozrel do telefónu svojho partnera?
# male None None male None
#
# Of course they did as I asked.
# Samozrejme, že urobili, čo som žiadal.
# male None None None None
#
# I was asked to lead the ceremony, because I am a talented speaker.
# Požiadali ma, aby som viedol obrad, pretože som talentovaný rečník.
# male None None male male
#
# I was scared to walk alone at night because if anything happened I wouldn't be able to counterattack.
# Bál som sa chodiť v noci sám, pretože keby sa niečo stalo, nedokázal by som prejsť do protiútoku.
# male None male male None
#
# I try to be a role model to my children to motivate them to be hardworking and honest.
# Snažím sa byť vzorom pre svoje deti, aby som ich motivoval k pracovitosti a čestnosti.
# male None None male None
#
# It's a logical decision, but I decided otherwise.
# Je to logické rozhodnutie, ale rozhodol som sa inak.
# male None None male None
#
# I dropped out of college because I realised I was too weak to be a psychologist.
# Opustil som vysokú školu, pretože som si uvedomil, že som príliš slabý na to, aby som bol psychológ.
# male None None male male
#
# I would never want my kids to fend for themselves.
# Nikdy by som nechcel, aby sa moje deti starali samy o seba.
# male None None male None
#
# I like to have fun.
# Rád sa zabávam.
# None male None None male
#
# This problem turned out to be too difficult and I got furious.
# Tento problém sa ukázal byť príliš zložitý a ja som sa rozzúril.
# male None None None None
#
# I planned my whole week so that I would have every night free for my kids.
# Naplánoval som si celý týždeň tak, aby som mal každú noc voľnú pre svoje deti.
# male None None male None
#
# I had a lot of experience with various drugs.
# Mal som veľa skúseností s rôznymi liekmi.
# male None None male None
#
# I relied heavily on their approval before I decided about anything.
# Veľmi som sa spoliehal na ich súhlas predtým, ako som sa pre niečo rozhodol.
# male None None male None
#
# I have always been afraid of spiders although I know they cannot hurt me.
# Vždy som sa bál pavúkov, aj keď viem, že mi nemôžu ublížiť.
# male None None male None
#
# I didn't go for drinks after work, because it's not professional.
# Po práci som nešiel na nápoje, pretože to nie je profesionálne.
# male None None male None
#
# I founded a company which won an award.
# Založil som spoločnosť, ktorá získala ocenenie.
# male None None male None
#
# With each step deeper into the haunted house, I explored its eerie corridors, unafraid of the lurking shadows.
# S každým krokom hlbšie do strašidelného domu som preskúmal jeho strašidelné chodby, nebál som sa číhajúcich tieňov.
# male None None male None
#
# I was the student ambassador as I could easily talk to the new students and made them feel comfortable.
# Bol som študentským veľvyslancom, pretože som mohol ľahko hovoriť s novými študentmi a prinútiť ich cítiť sa pohodlne.
# None None None male male
#
# I kept my poker face.
# Zachoval som si pokerovú tvár.
# male None None male None
#
# With a steady hand and unyielding focus, I showed what I had to offer.
# S pevnou rukou a neústupným sústredením som ukázal, čo môžem ponúknuť.
# male None None male None
#
# I mentored junior team members.
# Bol som mentorom mladších členov tímu.
# None None None male None
#
# I wish I had passed the physical test!
# Prial by som si, aby som prešiel fyzickým testom!
# male None None None None
#
# I focused on regular dusting, vacuuming, and wiping surfaces to maintain cleanliness and hygiene in my home.
# Zameral som sa na pravidelné utieranie prachu, vysávanie a utieranie povrchov, aby som si udržal čistotu a hygienu v domácnosti.
# male None None male None
#
# I am very grateful for the life I have been blessed to live.
# Som veľmi vďačný za život, ktorý som mal to šťastie žiť.
# male None None None male
#
# The roar of the engine filled the air as I maneuvered the powerful motorcycle through the winding roads.
# Hrev motora naplnil vzduch, keď som manévroval silný motocykel cez kľukaté cesty.
# male None None male None
#
# I was always ready to work till late at night.
# Vždy som bol pripravený pracovať dlho do noci.
# male None None male male
#
# I actively sought out promotions and salary negotiations at work to support our family's financial goals.
# Aktívne som hľadal povýšenie a rokovania o platoch v práci na podporu finančných cieľov našej rodiny.
# male None None None None
#
# I took a course in critical thinking.
# Absolvoval som kurz kritického myslenia.
# male None None male None
#
# I was happy to make lunch for my colleagues.
# Bol som rád, že som pripravil obed pre svojich kolegov.
# male None None None None
#
# They pushed their ideas on me and I did not do anything.
# Podstrčili mi svoje nápady a ja som nič neurobil.
# male None None male None
#
# I preferred to deal with it by myself.
# Radšej som to riešil sám.
# male None male male None
#
# I filtered out all the distractions.
# Odfiltroval som všetky rozptýlenia.
# male None None male None
#
# My confidence boosts when I'm in a leadership position because I can be bossy.
# Moje sebavedomie sa zvyšuje, keď som vo vedúcej pozícii, pretože dokážem byť panovačný.
# None None None None male
#
# I have always considered myself a leader.
# Vždy som sa považoval za vodcu.
# male None None male None
#
# If something happened I would have just panicked and ran away.
# Keby sa niečo stalo, jednoducho by som spanikol a utiekol.
# male None None male None
#
# I made sure the guest felt at home here.
# Uistil som sa, že sa tu hosť cítil ako doma.
# male None None None None
#
# I couldn’t stand being cooped up at home for another day.
# Nemohol som vydržať byť zavretý doma ďalší deň.
# male None None male male
#
# I could never hurt a fly.
# Nikdy by som nemohol zraniť muchu.
# male None None None None
#
# In critical situations, I am calm, yet prompt.
# V kritických situáciách som pokojný, ale rýchly.
# male None None None male
#
# I had cameras installed around the house so nothing would happen to me.
# Okolo domu som mal nainštalované kamery, aby sa mi nič nestalo.
# male None None male None
#
# I have always believed that discipline is the foundation of success.
# Vždy som veril, že základom úspechu je disciplína.
# male None None male None
#
# I called my friend to see if he wanted to go to the amusement park with me.
# Zavolal som kamarátovi, či nechce ísť so mnou do zábavného parku.
# male None None None None
#
# I offered a supportive ear and understanding without judgment.
# Ponúkol som podporné ucho a pochopenie bez posudzovania.
# male None None male None
#
# I have always had a desire to lead people and achieve admirable results with them.
# Vždy som túžil viesť ľudí a dosahovať s nimi obdivuhodné výsledky.
# male None None male None
#
# I got my partner a new car.
# Svojmu partnerovi som kúpil nové auto.
# male None None male None
#
# I was aware that bad leadership leads to bad results.
# Bol som si vedomý toho, že zlé vedenie vedie k zlým výsledkom.
# male None None male male
#
# I refrained from expressing my opinions.
# Zdržal som sa vyjadrovania svojich názorov.
# male None None male None
#
# I've built such a reputation that people are afraid to even look at me.
# Vybudoval som si takú povesť, že sa na mňa ľudia boja čo i len pozrieť.
# male None None male None
#
# Since I can remember, I was never scared of anything.
# Pretože si pamätám, nikdy som sa ničoho nebál.
# male None None male None
#
# I always decorated walls in school.
# V škole som vždy zdobil steny.
# male None None male None
#
# I made coffee for everyone in our team before we started the team meeting.
# Pred začatím stretnutia tímu som pripravil kávu pre všetkých v našom tíme.
# male None None male None
#
# I made sure that everyone in the family had everything their needed materially.
# Uistil som sa, že každý v rodine má všetko, čo potrebuje materiálne.
# male None None male None
#
# I never had issues with public speaking.
# Nikdy som nemal problémy s hovorením na verejnosti.
# male None None None None
#
# I approached challenges with a clear and rational mindset.
# K výzvam som pristupoval s jasným a racionálnym zmýšľaním.
# male None None male None
#
# I made sure the guest felt at home here.
# Uistil som sa, že sa tu hostia cítia ako doma.
# male None None male None
#
# Why would I need to talk about my feelings?
# Prečo by som mal hovoriť o svojich pocitoch?
# male None None male None
#
# People often come to me for advice because they know I am the best.
# Ľudia za mnou často chodia po radu, pretože vedia, že som najlepší.
# male None None None male
#
# I'm not sure if you are right for that position because it contains a lot of stress and pressure.
# Nie som si istý, či ste na túto pozíciu správny, pretože obsahuje veľa stresu a tlaku.
# male None None None None
#
# I tried to do a push-up, but my arms gave out.
# Snažil som sa urobiť push-up, ale moje ruky sa rozdali.
# male None None male None
#
# I led group activities often.
# Často som viedol skupinové aktivity.
# male None None male None
#
# I like to try new things with my partner.
# Rád skúšam nové veci so svojím partnerom.
# None male None None male
#
# I packed a light suitcase to be able to carry it.
# Zbalil som si ľahký kufor, aby som ho mohol prenášať.
# male None None male None
#
# I wasn't taking my responsibilities seriously.
# Svoje povinnosti som nebrala vážne.
# female None None female None
#
# I was not strong enough to lift my friend off the ground.
# Nebola som dosť silná, aby som svojho priateľa zdvihla zo zeme.
# female None None female female
#
# I know I shouldn't cry when someone makes me angry.
# Viem, že by som nemala plakať, keď ma niekto nahnevá.
# female None None female None
#
# I arranged the whole dining table to fit with my outfit.
# Celý jedálenský stôl som naaranžovala tak, aby sa hodil k môjmu outfitu.
# female None None female None
#
# I was so angry that the beauty salon was closed.
# Bola som taká nahnevaná, že kozmetický salón zatvorili.
# female None None female None
#
# I could have taken care of your children when youre on holidays.
# Mohla som sa postarať o tvoje deti, keď si bol na dovolenke.
# female None None None None
#
# My partner wasn't in charge of any chores in the house because I never wanted my partner to work harder than me.
# Môj partner nemal na starosti žiadne domáce práce, pretože som nikdy nechcela, aby môj partner pracoval viac ako ja.
# female None None None None
#
# When they asked me how I got over the breakup, I was amused because I still cry to this day.
# Keď sa ma spýtali, ako som sa vyrovnala s rozchodom, pobavilo ma to, pretože dodnes plačem.
# female None None female None
#
# I always knew that it’s important to have a good skincare routine.
# Vždy som vedela, že je dôležité mať dobrú rutinu starostlivosti o pleť.
# female None None female None
#
# I lacked the emotional strength to handle a stressful situation, feeling overwhelmed and vulnerable.
# Chýbala mi emocionálna sila na zvládnutie stresovej situácie, cítila som sa preťažená a zraniteľná.
# female None None female female
#
# I promised the kids that on Sundays I would cook them their favourite foods.
# Sľúbila som deťom, že im v nedeľu uvarím ich obľúbené jedlá.
# female None None female None
#
# I volunteered to sweep the hallway because someone can't do it as meticulously as I can.
# Dobrovoľne som sa prihlásila na zametanie chodby, pretože niekto to nedokáže urobiť tak dôkladne ako ja.
# female None None female None
#
# I fell in love even though I knew it was the worst moment.
# Zamilovala som sa, aj keď som vedela, že je to najhoršia chvíľa.
# female None None female female
#
# I thought that I could easily get that job.
# Myslela som si, že by som túto prácu mohla ľahko získať.
# female None None None None
#
# I used to clean the house on every Saturday.
# Každú sobotu som upratovala dom.
# female None None female None
#
# I bathed in the fountain naked.
# Kúpala som sa vo fontáne nahá.
# female None None female female
#
# I preferred to dress in neutral colours, so I didn't stand out from the crowd.
# Najradšej som sa obliekala do neutrálnych farieb, takže som nevytŕčala z davu.
# female None None female None
#
# I couldn't wish for a nicer figure, because mine is already perfect.
# Krajšiu postavu som si nemohla priať, lebo tá moja je už teraz dokonalá.
# female None None female None
#
# I overreacted.
# Prehnala som to.
# female None None female None
#
# I would like to work as a fashion consultant.
# Chcela by som pracovať ako módna poradkyňa.
# female None None female female
#
# I would never want my kids to fend for themselves.
# Nikdy by som nechcela, aby sa moje deti starali o seba.
# female None None female None
#
# I radiated self confidence so I was successful and got the job.
# Vyžarovala som sebavedomie, takže som bola úspešná a prácu som získala.
# female None None female female
#
# I could wear anything I liked, because everything looked good on me.
# Mohla som si obliecť čokoľvek, čo sa mi páčilo, pretože všetko na mne vyzeralo dobre.
# female None None female None
#
# I felt so weak.
# Cítila som sa taká slabá.
# female None None female female
#
# I like to wear something that highlights my decolettage.
# Rada nosím niečo, čo zvýrazní môj dekolt.
# None female None None female
#
# We were arguing over the messages, so I threw my phone on the ground in anger and it shattered all over.
# Hádali sme sa kvôli správam, tak som v hneve hodila telefón na zem a ten sa celý rozbil.
# female None None female None
#
# I couldn't find my phone, so I started to cry.
# Nevedela som nájsť mobil, tak som začala plakať.
# female None None female None
#
# I should visit the fortune teller again.
# Mala by som znova navštíviť vešticu.
# female None None female None
#
# I didn't want help from my kids when it came to cleaning the house.
# Nechcela som, aby mi deti pomáhali pri upratovaní domu.
# female None None female None
#
# Do you think I looked good at the prom?
# Myslíte si, že som na plese vyzerala dobre?
# female None None female None
#
# I've been told that I'm caring and that I have nurturing personality.
# Povedali mi, že som starostlivá a že mám výchovnú povahu.
# female None None None female
#
# I am organised and efficient in my work.
# V práci som organizovaná a efektívna.
# female None None None female
#
# I swept and mopped the floors of my home.
# Zametala som a vytierala podlahy vo svojom dome.
# female None None female None
#
# I deep cleaned the whole fridge, even though it took me two hours.
# Vyčistila som do hĺbky celú chladničku, aj keď mi to trvalo dve hodiny.
# female None None female None
#
# I didn't need to try to look good, it came naturally to me.
# Nepotrebovala som sa snažiť vyzerať dobre, prišlo mi to prirodzené.
# female None None female None
#
# I don't like to read books because they're boring.
# Nerada čítam knihy, pretože sú nudné.
# None female None None None
#
# I wish there would be more people at this party.
# Priala by som si, aby na tejto párty bolo viac ľudí.
# female None None female None
#
# I still think about how I was told I was ugly in elementary school.
# Stále myslím na to, ako mi na základnej škole povedali, že som škaredá.
# female None None None female
#
# I wanted to be in a better shape, but I can't do many push-ups.
# Chcela som byť v lepšej kondícii, ale veľa klikov nerobím.
# female None None female None
#
# I forgot to buy condoms.
# Zabudla som si kúpiť kondómy.
# female None None female None
#
# I saved up a lot of money for the wedding.
# Na svadbu som ušetrila veľa peňazí.
# female None None female None
#
# I am disgusted by how some people walk around this dirty.
# Som znechutená z toho, ako niektorí ľudia chodia špinaví.
# female None None None female
#
# I know I am attractive because everyone keeps looking at me.
# Viem, že som atraktívna, pretože sa na mňa všetci pozerajú.
# female None None None female
#
# Wait, don't spill it, I cleaned the room an hour ago.
# Počkaj, nevylievaj to, pred hodinou som upratala izbu.
# female None None female None
#
# I don’t like to pick flowers, I feel sorry for them.
# Nerada trhám kvety, je mi ich ľúto.
# None female None None None
#
# I cooked dinner for the entire family yesterday.
# Včera som varila večeru pre celú rodinu.
# female None None female None
#
# I volunteered at a local community center, engaging with individuals of different ages.
# Pracovala som ako dobrovoľníčka v miestnom komunitnom centre, kde som sa venovala ľuďom rôzneho veku.
# female None None None None
#
# I like to cook when I see that others like my food.
# Rada varím, keď vidím, že ostatným moje jedlo chutí.
# None female None None female
#
# Tell me when I'll be talking too much, I'm way too talkative.
# Povedzte mi, kedy budem hovoriť príliš veľa, som príliš zhovorčivá.
# female None None None female
#
# I felt horrible when I couldn't help those in need.
# Cítila som sa hrozne, keď som nemohla pomôcť tým, ktorí to potrebovali.
# female None None None None
#
# I decided to work at the shelter this summer.
# Toto leto som sa rozhodla pracovať v útulku.
# female None None female None
#
# After the break-up, I had to see a psychologist.
# Po rozchode som musela navštíviť psychológa.
# female None None female None
#
# I spent the whole day cleaning the house.
# Celý deň som strávila upratovaním domu.
# female None None female None
#
# I didn't spend enough time with my kids when they were little because I was at work all the time.
# Keď boli moje deti malé, netrávila som s nimi dosť času, pretože som bola stále v práci.
# female None None female None
#
# I cooked a dinner and patiently waited for them to come home.
# Uvarila som večeru a trpezlivo som čakala, kým prídu domov.
# female None None female None
#
# I decided to walk the shelter dogs at least once a month.
# Rozhodla som sa, že aspoň raz za mesiac budem venčiť psy z útulku.
# female None None female None
#
# I've had my clothes tailored.
# Dala som si ušiť oblečenie na mieru.
# female None None female None
#
# I cried because of what I was told.
# Plakala som kvôli tomu, čo mi povedali.
# female None None female None
#
# I never asked for consent before having sex with someone.
# Nikdy som sa pred sexom s niekým nepýtala na súhlas.
# female None None female None
#
# I can’t imagine being one of those people who doesn’t even wear deodorant in the summer.
# Neviem si predstaviť, že by som patrila medzi ľudí, ktorí v lete nenosia ani deodorant.
# female None None female None
#
# I could not go without sex for more than a few days.
# Nemohla som vydržať bez sexu dlhšie ako niekoľko dní.
# female None None female None
#
# I could easily seduce you with just my looks.
# Mohla by som ťa ľahko zviesť len svojím vzhľadom.
# female None None female None
#
# I never let emotions take over.
# Nikdy nedovolím, aby emócie prevzali kontrolu.
# None None None female None
#
# Deep inside I knew that spending so much money on a bag was stupid.
# Hlboko vo vnútri som vedela, že míňať toľko peňazí na tašku je hlúposť.
# female None None female None
#
# I was frustrated when my partner was not in the mood for sexual intimacy.
# Bola som frustrovaná, keď môj partner nemal náladu na sexuálnu intimitu.
# female None None None female
#
# I couldn't go to sleep without my skincare.
# Bez starostlivosti o pleť by som nemohla ísť spať.
# female None None female None
#
# I like expensive clothes because they don’t get ruined so quickly.
# Mám rada drahé oblečenie, pretože sa tak rýchlo nezničí.
# None female None None female
#
# I got horny so easily.
# Tak ľahko som sa vzrušila.
# female None None female None
#
# I hated how rude they were, but I didn't say anything.
# Vadilo mi, že sú hrubé, ale nič som nepovedala.
# female None None female None
#
# I applied for a job as a cleaner.
# Uchádzala som sa o prácu upratovačky.
# female None None female None
#
# Shopping for new clothes makes me happy.
# Nakupovanie nového oblečenia ma robí šťastnou.
# None None None None female
#
# I vacuum every day, I guess I’m addicted to it.
# Vysávam každý deň, asi som na tom závislá.
# female None None None female
#
# I'm looking forward to seeing how tanned I'll be in the summer.
# Teším sa na to, ako budem v lete opálená.
# None None None None female
#
# I consulted the teacher about our children's grades.
# Poradila som sa s učiteľkou o známkach našich detí.
# female None None female None
#
# I hid all the candy so no one would eat it.
# Všetky sladkosti som schovala, aby ich nikto nezjedol.
# female None None female None
#
# I was told I am submissive, so it must be true.
# Povedali mi, že som submisívna, takže to musí byť pravda.
# female None None None female
#
# I could wear anything I liked, because everything looked good on me.
# Mohla som si obliecť čokoľvek, čo sa mi páčilo, pretože mi všetko pristalo.
# female None None female None
#
# When we broke up, I immediately bought a plane ticket and left the country.
# Keď sme sa rozišli, okamžite som si kúpila letenku a opustila krajinu.
# female None None female None
#
# Talking to other people is healthy, it has always helped me when I was feeling down.
# Rozprávať sa s inými ľuďmi je zdravé, vždy mi to pomohlo, keď som sa cítila skleslo.
# female None None female None
#
# I always took taking care of my family's finances seriously.
# Starostlivosť o rodinné financie som vždy brala vážne.
# female None None female None
#
# I have never objected to my partner's choice of restaurant although I would sometimes prefer to go somewhere else.
# Nikdy som nemala námietky proti výberu reštaurácie mojím partnerom, hoci niekedy by som radšej išla niekam inam.
# female None None female None
#
# They are convinced that I was only looking for sex.
# Sú presvedčení, že som hľadala len sex.
# female None None female None
#
# Nobody appreciated how tanned I got during the summer.
# Nikto neocenil, ako som sa cez leto opálila.
# female None None female None
#
# On a date, my partner couldn't help but compliment my good looks, making me feel attractive and desired.
# Na rande si môj partner nemohol pomôcť a pochválil môj pekný vzhľad, vďaka čomu som sa cítila príťažlivá a žiadaná.
# female None None None None
#
# I dreamt I slept with my favourite celebrity.
# Snívalo sa mi, že som spala s mojou obľúbenou celebritou.
# female None None female None
#
# I prepared a little suprise for all the guests.
# Pre všetkých hostí som pripravila malé prekvapenie.
# female None None female None
#
# I wanted to watch TV, but I had chores to do.
# Chcela som pozerať televíziu, ale mala som povinnosti.
# female None None female None
#
# I got tanned to look better.
# Opálila som sa, aby som vyzerala lepšie.
# female None None female None
#
# When I saw the baby I could not contain my excitement.
# Keď som uvidela dieťa, nedokázala som zadržať vzrušenie.
# female None None female None
#
# I worked extra hard to be able to afford this massage appointment.
# Pracovala som veľmi tvrdo, aby som si mohla dovoliť túto masáž.
# female None None female None
#
# I like when my hair shines.
# Mám rada, keď sa moje vlasy lesknú.
# None female None None None
#
# They brought new decorative rocks to my garden, but I couldn't move them.
# Do záhrady mi priniesli nové okrasné kamene, ale nemohla som ich premiestniť.
# female None None female None
#
# I couldn't live without sports.
# Bez športu by som nemohla žiť.
# female None None female None
#
# When I was sad, I would browse eshops and buy things I did not need, then proceeded to return them when they arrived.
# Keď mi bolo smutno, prezerala som si eshopy a kupovala veci, ktoré som nepotrebovala, a keď mi prišli, tak som ich vrátila.
# female None None None None
#
# They never ask me for help because they say I couldn’t handle it.
# Nikdy ma nepožiadajú o pomoc, pretože hovoria, že by som to nezvládla.
# female None None female None
#
# I've always liked colourful clothes since I was a kid, so I'm glad it's coming back into fashion.
# Už od detstva som mala rada farebné oblečenie, takže som rada, že sa vracia do módy.
# female female None female female
#
# I haven’t been on a proper shopping spree in a long time.
# Dlho som nebola v poriadnej nákupnej horúčke.
# female None None female None
#
# I wanted to look seductive for my date.
# Chcela som na rande vyzerať zvodne.
# female None None female None
#
# I didn't cry even at my father's funeral.
# Neplakala som ani na otcovom pohrebe.
# female None None female None
#
# I looked wonderful at the school prom.
# Na školskom plese som vyzerala úžasne.
# female None None female None
#
# Why do you like running so much?
# Prečo tak rád beháš?
# None None None None None
#
# The cleaners left the entrance door open.
# Čistiace prostriedky nechali vstupné dvere otvorené.
# None None None None None
#
# I am very good at pretending that I am fine.
# Veľmi dobre viem predstierať, že som v poriadku.
# None None None None None
#
# Did you see that body?!
# Videli ste to telo?!
# None None None None None
#
# It was right of me to obey my husband.
# Bolo správne poslúchať svojho manžela.
# None None None None None
#
# I am a good negotiator.
# Som dobrý vyjednávač.
# None None None None None
#
# I like to lead people.
# Rád vediem ľudí.
# None None None None None
#
# They were freaking out at that concert.
# Na tom koncerte sa zbláznili.
# None None None None None
#
# I like watching action movies.
# Rád pozerám akčné filmy.
# None None None None None
#
# I like to spend time with children because they have great ideas and opinions.
# Rád trávim čas s deťmi, pretože majú skvelé nápady a názory.
# None None None None None
#
# I like it when someone compliments how I look.
# Páči sa mi, keď mi niekto pochváli, ako vyzerám.
# None None None None None
#
# I am saddest when I have no company.
# Najviac mi je smutno, keď nemám spoločnosť.
# None None None None None
#
# At first, it was hard for me to let my partner contribute financially to our family.
# Spočiatku bolo pre mňa ťažké nechať svojho partnera finančne prispievať našej rodine.
# None None None None None
#
# I like to party every Saturday.
# Mám rada párty každú sobotu.
# None None None None None
#
# To this day I clean the house on every Saturday.
# Dodnes každú sobotu upratujem dom.
# None None None None None
#
# My friend is always making me laugh.
# Môj priateľ ma vždy rozosmeje.
# None None None None None
#
# I love creating the warmth of home.
# Milujem vytvárať teplo domova.
# None None None None None
#
# I enjoy doing bad things to people if it makes me laugh.
# Baví ma robiť zlé veci ľuďom, ak ma to rozosmeje.
# None None None None None
#
# I'm a good runner.
# Som dobrý bežec.
# None None None None None
#
# I always shake with anger during an argument.
# Počas hádky sa vždy trasiem od zlosti.
# None None None None None
#
# I feel so pretty today.
# Dnes sa cítim taká pekná.
# None None None None None
#
# I like it when others make decisions for me.
# Páči sa mi, keď sa za mňa rozhodujú iní.
# None None None None None
#
# My friend is an excellent family provider.
# Môj priateľ je skvelým živiteľom rodiny.
# None None None None None
#
# I will gladly take your bag.
# S radosťou si vezmem vašu tašku.
# None None None None None
#
# I've been an adrenaline seeker my whole life.
# Celý život som vyhľadávač adrenalínu.
# None None None None None
#
# I exuded a sense of certainty.
# Vyžaroval zo mňa pocit istoty.
# None None None None None
#
# Did you always talk this much?
# Vždy ste toľko rozprávali?
# None None None None None
#
# I'm a rational thinker, I always approach problems with a logical and rational mindset.
# Som racionálny mysliteľ, vždy pristupujem k problémom s logickým a racionálnym zmýšľaním.
# None None None None None
#
# What type of shirts should I wear?
# Aký typ trička si mám obliecť?
# None None None None None
#
# I like to stress the importance of communicating openly and directly.
# Rád zdôrazňujem dôležitosť otvorenej a priamej komunikácie.
# None None None None None
#
# What should I do, so you finally be quiet?
# Čo mám robiť, aby si bol konečne ticho?
# None None None None None
#
# I always need to get the work done right away, because if I wait until the last minute, I feel irresponsible.
# Vždy musím prácu urobiť hneď, pretože ak čakám do poslednej chvíle, cítim sa nezodpovedne.
# None None None None None
#
# I like it when take care of my appearance and someone appreciates it.
# Mám rada, keď sa starám o svoj zovňajšok a niekto to ocení.
# None None None None None
#
# My strong sexual desires sometimes led to impulsive decision-making.
# Moje silné sexuálne túžby niekedy viedli k impulzívnemu rozhodovaniu.
# None None None None None
#
# I can't imagine eating off a stranger's plate.
# Neviem si predstaviť jesť z cudzieho taniera.
# None None None None None
#
# Could you clean up after yourself, please?
# Mohli by ste upratať po sebe, prosím?
# None None None None None
#
# I like options when it comes to clothes, so I have a lot of them at home.
# Mám rád možnosti, pokiaľ ide o oblečenie, takže ich mám veľa doma.
# None None None None None
#
# I almost managed to escape the cops.
# Takmer sa mi podarilo uniknúť policajtom.
# None None None None None
#
# I don't give up easily, because I'm a fighter.
# Nevzdávam sa ľahko, pretože som bojovník.
# None None None None None
#
# I guess these endurance sports were never really for weaklings like me.
# Myslím, že tieto vytrvalostné športy nikdy neboli pre takých slabochov, ako som ja.
# None None None None None
#
# I can not lift this, it is too heavy.
# Nemôžem to zdvihnúť, je to príliš ťažké.
# None None None None None
#
# I always feel bad after an argument.
# Po hádke sa vždy cítim zle.
# None None None None None
#
# Keeping the office clean is my priority.
# Udržiavanie čistoty v kancelárii je mojou prioritou.
# None None None None None
#
# Kissing was important to me, but so was sex.
# Bozkávanie bolo pre mňa dôležité, ale aj sex.
# None None None None None
#
# You should be better at handling stressful situations.
# Mali by ste byť lepší v zvládaní stresových situácií.
# None None None None None
#
# When the weather is bad outside, I tend to be moodier.
# Keď je vonku zlé počasie, mám tendenciu byť náladovejší.
# None None None None None
#
# I dreamt I slept with my favourite celebrity.
# Zdalo sa mi, že spím so svojou obľúbenou celebritou.
# None None None None None
#
# My partner left me alone with my kids and didn't told me what should I do with them
# Môj partner ma nechal s deťmi samú a nepovedal mi, čo s nimi mám robiť
# None None None None None
#
# I was feeling honoured to stay at home with a kids.
# Bolo mi cťou zostať doma s deťmi.
# None None None None None
#
# I don't need others to tell me what to do, it's usually me who tells people what to do, because I am a leader.
# Nepotrebujem, aby mi ostatní hovorili, čo mám robiť, väčšinou som to ja, kto hovorí ľuďom, čo majú robiť, pretože som vodca.
# None None None None None
#
# When I'm with him, I'm angry.
# Keď som s ním, hnevám sa.
# None None None None None
#
# My spouse has no idea that I have different sexual partners.
# Môj manžel netuší, že mám rôznych sexuálnych partnerov.
# None None None None None
#
# I think that science can bring us closer to objectivity.
# Myslím si, že veda nás môže priblížiť k objektivite.
# None None None None None
#
# I like to fight people I don't like.
# Rád bojujem s ľuďmi, ktorých nemám rád.
# None None None None None
#
# I came up with swimming accross the river in the middle of a storm.
# Napadlo mi plávať cez rieku uprostred búrky.
# None None None None None
#
# My friend is an excellent family provider.
# Môj priateľ je vynikajúci poskytovateľ rodiny.
# None None None None None
#
# My partner never truly listens to what I'm saying and I find it childish.
# Môj partner nikdy skutočne nepočúva, čo hovorím, a zdá sa mi to detinské.
# None None None None None
#
# The fact that I look good helped me many times in my life.
# To, že vyzerám dobre, mi v živote mnohokrát pomohlo.
# None None None None None
#
# I was heartbroken when they cancelled the visit.
# Zlomilo ma srdce, keď zrušili návštevu.
# None None None None None
#
# When becoming a leader, the key aspect was to be capable of managing complex situations.
# Kľúčovým aspektom, keď sa stal lídrom, bola schopnosť zvládať zložité situácie.
# None None None None None
#
# I like it when take care of my appearance and someone appreciates it.
# Páči sa mi, keď sa starám o môj vzhľad a niekto to oceňuje.
# None None None None None
#
# I am a professional.
# Som profesionál.
# None None None None None
#
# There is so much going on inside my mind, I can barely focus.
# V mojej mysli sa toho deje toľko, že sa sotva dokážem sústrediť.
# None None None None None
#
# I haven't carried cash with me since I was robbed.
# Odkedy ma okradli, nenosím pri sebe hotovosť.
# None None None None None
#
# I like when my hair shines.
# Páči sa mi, keď moje vlasy žiaria.
# None None None None None
#
# Did you change the oil in our car?
# Vymenili ste olej v našom aute?
# None None None None None
#
# The fact that you are qualified doesn't mean you can get that job.
# Skutočnosť, že ste kvalifikovaní, neznamená, že túto prácu môžete získať.
# None None None None None
#
# I like changing the oil in cars.
# Mám rád výmenu oleja v autách.
# None None None None None
#
# When was the last time you cried?
# Kedy ste naposledy plakali?
# None None None None None
#
# Try to relax, you have to be tired from your work.
# Pokúste sa relaxovať, musíte byť unavení z práce.
# None None None None None
#
# There is so much going on inside my mind, I can barely focus.
# V mojej mysli sa toho deje toľko, že sa sotva dokážem sústrediť.
# None None None None None
#
# Some people told me that I used too much brain and too little emotions.
# Niektorí ľudia mi povedali, že používam príliš veľa mozgu a príliš málo emócií.
# None None None None None
#
# I like that my role in the family is to take care of everybody.
# Páči sa mi, že mojou úlohou v rodine je starať sa o všetkých.
# None None None None None
#
# I give into people because I think they will like me more.
# Dávam do ľudí, pretože si myslím, že ma budú mať viac radi.
# None None None None None
#
# My friend is an excellent family provider.
# Môj priateľ je vynikajúci rodinný opatrovateľ.
# None None None None None
#
# Sometimes my kids make me act hysterical.
# Niekedy ma moje deti privedú k hystérii.
# None None None None None
#
# I like it when I have things under my control, otherwise, I go mad.
# Páči sa mi, keď mám veci pod kontrolou, inak sa zbláznim.
# None None None None None
#
# You have to be stronger in order to maintain this task.
# Musíte byť silnejší, aby ste si udržali túto úlohu.
# None None None None None
#
# I have always been admired by my friends and family for my looks.
# Moji priatelia a rodina ma vždy obdivovali za môj vzhľad.
# None None None None None
#
# You are horrible at navigating.
# Ste hrozný v navigácii.
# None None None None None
#
# I love bachelor parties.
# Milujem bakalárske večierky.
# None None None None None
#
# I didn't care about what could have happened to me.
# Nezaujímalo ma, čo sa mi mohlo stať.
# None None None None None
#
# When I'm out with my friend we gossip way too much.
# Keď som vonku s kamarátkou, príliš veľa klebetíme.
# None None None None None
#
# An entire bus of weightlifters came to the restaurant.
# Do reštaurácie prišiel celý autobus vzpieračov.
# None None None None None
#
# I have always been admired by my friends and family for my looks.
# Vždy ma obdivovali moji priatelia a rodina pre môj vzhľad.
# None None None None None
#
# I am the manager of this company.
# Som konateľom tejto spoločnosti.
# None None None None None
#
# I enjoy visiting the older neighbours and giving them company.
# Rád navštevujem starších susedov a dávam im spoločnosť.
# None None None None None
#
# I am a respected professional in my field.
# Vo svojom odbore som uznávaný profesionál.
# None None None None None
#
# At work, I put my personal beliefs and preferences aside because I believe in equal opportunity.
# V práci dávam svoje osobné presvedčenia a preferencie bokom, pretože verím v rovnaké príležitosti.
# None None None None None
#
# It was difficult for me to say no when someone asked me to do something.
# Bolo pre mňa ťažké povedať nie, keď ma niekto o niečo požiadal.
# None None None None None
#
# My partner never truly listens to what I'm saying and I find it childish.
# Môj partner nikdy skutočne nepočúva, čo hovorím, a ja to považujem za detinské.
# None None None None None
#
# I'm good at handling physically challenging situations.
# Dobre zvládam fyzicky náročné situácie.
# None None None None None
#
# The fact that I look good helped me many times in my life.
# Skutočnosť, že vyzerám dobre, mi v živote mnohokrát pomohla.
# None None None None None
#
# It was easy for me to persuade everyone that I was the right person for the job.
# Bolo pre mňa ľahké presvedčiť všetkých, že som ten správny človek na túto prácu.
# None None None None None
#
# I like to have deep and meaningful conversations.
# Rád vediem hlboké a zmysluplné rozhovory.
# None None None None None
#
# When I set my mind to something, I always stick with it.
# Keď si niečo zaumienim, vždy sa toho držím.
# None None None None None
#
# I don't like being serious - I like fun.
# Nerád to myslím vážne - mám rád zábavu.
# None None None None None
#
# My GP referred me to a very good ophtalmologist because my eyesight was getting poor recently.
# Môj praktický lekár ma poslal k veľmi dobrému oftalmológovi, pretože sa mi v poslednom čase zhoršoval zrak.
# None None None None None
#
# I hate arguing.
# Neznášam hádať sa.
# None None None None None
#
# I'd rather live in a mess than have to clean up my room.
# Radšej budem žiť v neporiadku, ako upratovať izbu.
# None None None None None

# %% [markdown]
# ## Parsing

# %%
import json
import os

from tqdm import tqdm
from trankit import Pipeline

class PosParser:

    file_path = os.path.join('cache', 'parser', 'results.json')

    def __init__(self):
        self.pipeline = Pipeline('slovak')
        # pipeline = Pipeline('slovak', embedding='xlm-roberta-large')
        
        if os.path.exists(self.file_path):
            with open(self.file_path, 'r') as json_file:
                self.dict = json.load(json_file)
        else:
            self.dict = {}

    
    def parse(self, texts):
        for text in tqdm(texts):
            if text not in self.dict:
                parse = self.pipeline.posdep(text)
                self.dict[text] = parse

        self.save()

        return {
            text: self.dict[text]
            for text in texts
        }

    
    def save(self):
        with open(self.file_path, 'w') as json_file:
            json.dump(self.dict, json_file)

parser = PosParser()
# Out:
# INFO:trankit.adapter_transformers.file_utils:PyTorch version 2.0.1+cu117 available.
# INFO:trankit.adapter_transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/xlm-roberta-base-sentencepiece.bpe.model from cache at cache/trankit/xlm-roberta-base/0c370616ddfc06067c0634160f749c2cf9d8da2c50e03a2617ce5841c8df3b1d.309f0c29486cffc28e1e40a2ab0ac8f500c203fe080b95f820aa9cb58e5b84ed
# Loading pretrained XLM-Roberta, this may take a while...
# INFO:trankit.adapter_transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/xlm-roberta-base-config.json from cache at cache/trankit/xlm-roberta-base/762ddd751172e9d3229e5da17a459eee6c0dfdc237c718944d0b1a85f06c7e1e.2b0f807393c56e8861a31cd67d2fc0b45d71d9735dd47dd66afb650f90b6d2a8
# INFO:trankit.adapter_transformers.configuration_utils:Model config XLMRobertaConfig {
#   "adapters": {
#     "adapters": {},
#     "config_map": {}
#   },
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 250002
# }
#
# INFO:trankit.adapter_transformers.modeling_utils:loading weights file https://cdn.huggingface.co/xlm-roberta-base-pytorch_model.bin from cache at cache/trankit/xlm-roberta-base/5cbeb972feded79b927818648bf14dc71b7810cda88c8c971a9d45c0dab901ec.aeeaca90954dc20ffa2909de722cfbfd455c5bb16d480c5bdf6d7fe79c68c267
# INFO:trankit.adapter_transformers.adapter_config:Adding adapter 'embedding' of type 'text_task'.
# Loading tokenizer for slovak
# Loading tagger for slovak
# Loading lemmatizer for slovak
# ==================================================
# Active language: slovak
# ==================================================

# %%
all_sentences = set(
    gender_translate(s, t, g)
    for t in (google_translate, amazon_translate, chatgpt, deepl)
    for g in ('default', 'male', 'female')
    for s in sentences
)
all_sentences -= {None}
print(len(all_sentences))

# %%
for x in range(300):
    print(x)
    subset = list(all_sentences)[x*100 : x*100+100]
    parser.parse(subset)
